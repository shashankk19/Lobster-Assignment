# %%
class centralNode:
    def __init__(self,value=None,right=None,left=None,labelled=False,nextNode=None):
        self.value=value
        self.right=right
        self.left=left
        self.labelled=labelled
        self.nextNode=nextNode

# %%
class rightNode:
    def __init__(self,value=None,children=None,labelled=False):
        self.value=value
        self.children = children if children is not None else []
        self.labelled=labelled
    def assignChildren(self,p):
        for i in range(p-1):
            self.children.append(leafNode(i+103))

# %%
class leftNode:
    def __init__(self,value=None,children=None,labelled=False):
        self.value=value
        self.children = children if children is not None else []
        self.labelled=labelled
    def assignChildren(self,p):
        for i in range(p-1):
            self.children.append(leafNode(i+105))

# %%
class leafNode:
    def __init__(self,value=None,labelled=False):
        self.value=value
        self.labelled=labelled

# %%
def create_lobster(n,p,prev,root,i):
    if n==0:
        return 
    a=centralNode(i*100)
    b=rightNode(i*101)
    c=leftNode(i*102)
    a.right=b
    a.left=c
    b.assignChildren(p)
    c.assignChildren(p)
#     print(len(b.children))
#     print(len(c.children))
    if prev!=None:
        prev.nextNode=a
    else:
        root=a
    create_lobster(n-1,p,a,root,i+1)
    return root

# %%
def printNodes(root):
    print(root.__class__.__name__)
    if root.__class__.__name__=="centralNode":
        print(root.value,"-->",root.right.value,"Edge weight:",root.value+root.right.value,":",root.value,"-->",root.left.value,"Edge weight:",root.value+root.left.value)
        printNodes(root.right)
#         print(root.right.children)
#         print(root.left.children)
        printNodes(root.left)
        printNodes(root.nextNode)
    elif root.__class__.__name__=="leftNode" or root.__class__.__name__=="rightNode":
        children=root.children
        for i in children:
            print(root.value,"-->",i.value,"Edge weight:",root.value+i.value)

# %%
def generateVerticesEdges(n,p):
    possible_vertices=[i for i in range(1,n*(2*p+1))]
    possible_edges={}
    for i in range(2,n*2*p+n+1):
        possible_edges[i]=1
    return possible_vertices,possible_edges

# %%
import math
def labelNodes(p,root,possible_vertices,possible_edges,min_key,track_nodes,nodes_dict):
    if root is None:
        return possible_edges,min_key
    if root.__class__.__name__=="centralNode":
        if root.labelled is False:
            root.value=1
        track_nodes+=1
        nodes_dict[track_nodes]=None
        min_search=math.floor(get_min(possible_edges)/2)
        for i in range(min_search-1,min_key):
            if root.value + possible_vertices[i] in possible_edges:
                root.right.value=possible_vertices[i]
                del possible_edges[root.value + possible_vertices[i]]
                min_key+=1
                break
        possible_edges,min_key,nodes_dict=labelNodes(p,root.right,possible_vertices,possible_edges,min_key,track_nodes,nodes_dict)
        root.left.value=math.floor((get_min(possible_edges)+p)/2)
        del possible_edges[root.value+root.left.value]
        min_key+=1
        possible_edges,min_key,nodes_dict=labelNodes(p,root.left,possible_vertices,possible_edges,min_key,track_nodes,nodes_dict)
        if root.nextNode:
            root.nextNode.value=get_min(possible_edges)-root.value
            del possible_edges[root.value+root.nextNode.value]
            root.nextNode.labelled=True
            min_key+=1
        possible_edges,min_key=labelNodes(p,root.nextNode,possible_vertices,possible_edges,min_key,track_nodes,nodes_dict)
        return possible_edges,min_key
    elif root.__class__.__name__=="leftNode" or root.__class__.__name__=="rightNode":
        if nodes_dict[track_nodes] is None:
            nodes_dict[track_nodes]=[]
            for child in root.children:
                min_search=math.floor(get_min(possible_edges)/2)
                for i in range(min_search-1,min_key):
                    weight=root.value+possible_vertices[i]
                    temp1=get_min(possible_edges)
                    if weight==temp1 and temp1 in possible_edges:
                        child.value=possible_vertices[i]
                        nodes_dict[track_nodes].append(child.value)
                        min_key+=1
                        del possible_edges[weight]
                        break
        else:
            temp=0 #1
            for child in root.children:
                child.value=nodes_dict[track_nodes][temp]
                del possible_edges[root.value+child.value]
                min_key+=1
                temp+=1
        return possible_edges,min_key,nodes_dict

# %%
def get_min(d):
    for i in d.keys():
        return i

# %%
import math,time
n=int(input("Enter n"))
p=int(input("Enter p"))
root=create_lobster(n,p,None,None,1)
possible_vertices,possible_edges=generateVerticesEdges(n,p)
start_time=time.time()
labelNodes(p,root,possible_vertices,possible_edges,2,0,{})
end_time=time.time()
print(end_time-start_time)
printNodes(root)
# Out:
# Enter n500
# Enter p500
# 4922.028997182846
# centralNode
# 1 --> 1 Edge weight: 2 : 1 --> 501 Edge weight: 502
# rightNode
# 1 --> 2 Edge weight: 3
# 1 --> 3 Edge weight: 4
# 1 --> 4 Edge weight: 5
# 1 --> 5 Edge weight: 6
# 1 --> 6 Edge weight: 7
# 1 --> 7 Edge weight: 8
# 1 --> 8 Edge weight: 9
# 1 --> 9 Edge weight: 10
# 1 --> 10 Edge weight: 11
# 1 --> 11 Edge weight: 12
# 1 --> 12 Edge weight: 13
# 1 --> 13 Edge weight: 14
# 1 --> 14 Edge weight: 15
# 1 --> 15 Edge weight: 16
# 1 --> 16 Edge weight: 17
# 1 --> 17 Edge weight: 18
# 1 --> 18 Edge weight: 19
# 1 --> 19 Edge weight: 20
# 1 --> 20 Edge weight: 21
# 1 --> 21 Edge weight: 22
# 1 --> 22 Edge weight: 23
# 1 --> 23 Edge weight: 24
# 1 --> 24 Edge weight: 25
# 1 --> 25 Edge weight: 26
# 1 --> 26 Edge weight: 27
# 1 --> 27 Edge weight: 28
# 1 --> 28 Edge weight: 29
# 1 --> 29 Edge weight: 30
# 1 --> 30 Edge weight: 31
# 1 --> 31 Edge weight: 32
# 1 --> 32 Edge weight: 33
# 1 --> 33 Edge weight: 34
# 1 --> 34 Edge weight: 35
# 1 --> 35 Edge weight: 36
# 1 --> 36 Edge weight: 37
# 1 --> 37 Edge weight: 38
# 1 --> 38 Edge weight: 39
# 1 --> 39 Edge weight: 40
# 1 --> 40 Edge weight: 41
# 1 --> 41 Edge weight: 42
# 1 --> 42 Edge weight: 43
# 1 --> 43 Edge weight: 44
# 1 --> 44 Edge weight: 45
# 1 --> 45 Edge weight: 46
# 1 --> 46 Edge weight: 47
# 1 --> 47 Edge weight: 48
# 1 --> 48 Edge weight: 49
# 1 --> 49 Edge weight: 50
# 1 --> 50 Edge weight: 51
# 1 --> 51 Edge weight: 52
# 1 --> 52 Edge weight: 53
# 1 --> 53 Edge weight: 54
# 1 --> 54 Edge weight: 55
# 1 --> 55 Edge weight: 56
# 1 --> 56 Edge weight: 57
# 1 --> 57 Edge weight: 58
# 1 --> 58 Edge weight: 59
# 1 --> 59 Edge weight: 60
# 1 --> 60 Edge weight: 61
# 1 --> 61 Edge weight: 62
# 1 --> 62 Edge weight: 63
# 1 --> 63 Edge weight: 64
# 1 --> 64 Edge weight: 65
# 1 --> 65 Edge weight: 66
# 1 --> 66 Edge weight: 67
# 1 --> 67 Edge weight: 68
# 1 --> 68 Edge weight: 69
# 1 --> 69 Edge weight: 70
# 1 --> 70 Edge weight: 71
# 1 --> 71 Edge weight: 72
# 1 --> 72 Edge weight: 73
# 1 --> 73 Edge weight: 74
# 1 --> 74 Edge weight: 75
# 1 --> 75 Edge weight: 76
# 1 --> 76 Edge weight: 77
# 1 --> 77 Edge weight: 78
# 1 --> 78 Edge weight: 79
# 1 --> 79 Edge weight: 80
# 1 --> 80 Edge weight: 81
# 1 --> 81 Edge weight: 82
# 1 --> 82 Edge weight: 83
# 1 --> 83 Edge weight: 84
# 1 --> 84 Edge weight: 85
# 1 --> 85 Edge weight: 86
# 1 --> 86 Edge weight: 87
# 1 --> 87 Edge weight: 88
# 1 --> 88 Edge weight: 89
# 1 --> 89 Edge weight: 90
# 1 --> 90 Edge weight: 91
# 1 --> 91 Edge weight: 92
# 1 --> 92 Edge weight: 93
# 1 --> 93 Edge weight: 94
# 1 --> 94 Edge weight: 95
# 1 --> 95 Edge weight: 96
# 1 --> 96 Edge weight: 97
# 1 --> 97 Edge weight: 98
# 1 --> 98 Edge weight: 99
# 1 --> 99 Edge weight: 100
# 1 --> 100 Edge weight: 101
# 1 --> 101 Edge weight: 102
# 1 --> 102 Edge weight: 103
# 1 --> 103 Edge weight: 104
# 1 --> 104 Edge weight: 105
# 1 --> 105 Edge weight: 106
# 1 --> 106 Edge weight: 107
# 1 --> 107 Edge weight: 108
# 1 --> 108 Edge weight: 109
# 1 --> 109 Edge weight: 110
# 1 --> 110 Edge weight: 111
# 1 --> 111 Edge weight: 112
# 1 --> 112 Edge weight: 113
# 1 --> 113 Edge weight: 114
# 1 --> 114 Edge weight: 115
# 1 --> 115 Edge weight: 116
# 1 --> 116 Edge weight: 117
# 1 --> 117 Edge weight: 118
# 1 --> 118 Edge weight: 119
# 1 --> 119 Edge weight: 120
# 1 --> 120 Edge weight: 121
# 1 --> 121 Edge weight: 122
# 1 --> 122 Edge weight: 123
# 1 --> 123 Edge weight: 124
# 1 --> 124 Edge weight: 125
# 1 --> 125 Edge weight: 126
# 1 --> 126 Edge weight: 127
# 1 --> 127 Edge weight: 128
# 1 --> 128 Edge weight: 129
# 1 --> 129 Edge weight: 130
# 1 --> 130 Edge weight: 131
# 1 --> 131 Edge weight: 132
# 1 --> 132 Edge weight: 133
# 1 --> 133 Edge weight: 134
# 1 --> 134 Edge weight: 135
# 1 --> 135 Edge weight: 136
# 1 --> 136 Edge weight: 137
# 1 --> 137 Edge weight: 138
# 1 --> 138 Edge weight: 139
# 1 --> 139 Edge weight: 140
# 1 --> 140 Edge weight: 141
# 1 --> 141 Edge weight: 142
# 1 --> 142 Edge weight: 143
# 1 --> 143 Edge weight: 144
# 1 --> 144 Edge weight: 145
# 1 --> 145 Edge weight: 146
# 1 --> 146 Edge weight: 147
# 1 --> 147 Edge weight: 148
# 1 --> 148 Edge weight: 149
# 1 --> 149 Edge weight: 150
# 1 --> 150 Edge weight: 151
# 1 --> 151 Edge weight: 152
# 1 --> 152 Edge weight: 153
# 1 --> 153 Edge weight: 154
# 1 --> 154 Edge weight: 155
# 1 --> 155 Edge weight: 156
# 1 --> 156 Edge weight: 157
# 1 --> 157 Edge weight: 158
# 1 --> 158 Edge weight: 159
# 1 --> 159 Edge weight: 160
# 1 --> 160 Edge weight: 161
# 1 --> 161 Edge weight: 162
# 1 --> 162 Edge weight: 163
# 1 --> 163 Edge weight: 164
# 1 --> 164 Edge weight: 165
# 1 --> 165 Edge weight: 166
# 1 --> 166 Edge weight: 167
# 1 --> 167 Edge weight: 168
# 1 --> 168 Edge weight: 169
# 1 --> 169 Edge weight: 170
# 1 --> 170 Edge weight: 171
# 1 --> 171 Edge weight: 172
# 1 --> 172 Edge weight: 173
# 1 --> 173 Edge weight: 174
# 1 --> 174 Edge weight: 175
# 1 --> 175 Edge weight: 176
# 1 --> 176 Edge weight: 177
# 1 --> 177 Edge weight: 178
# 1 --> 178 Edge weight: 179
# 1 --> 179 Edge weight: 180
# 1 --> 180 Edge weight: 181
# 1 --> 181 Edge weight: 182
# 1 --> 182 Edge weight: 183
# 1 --> 183 Edge weight: 184
# 1 --> 184 Edge weight: 185
# 1 --> 185 Edge weight: 186
# 1 --> 186 Edge weight: 187
# 1 --> 187 Edge weight: 188
# 1 --> 188 Edge weight: 189
# 1 --> 189 Edge weight: 190
# 1 --> 190 Edge weight: 191
# 1 --> 191 Edge weight: 192
# 1 --> 192 Edge weight: 193
# 1 --> 193 Edge weight: 194
# 1 --> 194 Edge weight: 195
# 1 --> 195 Edge weight: 196
# 1 --> 196 Edge weight: 197
# 1 --> 197 Edge weight: 198
# 1 --> 198 Edge weight: 199
# 1 --> 199 Edge weight: 200
# 1 --> 200 Edge weight: 201
# 1 --> 201 Edge weight: 202
# 1 --> 202 Edge weight: 203
# 1 --> 203 Edge weight: 204
# 1 --> 204 Edge weight: 205
# 1 --> 205 Edge weight: 206
# 1 --> 206 Edge weight: 207
# 1 --> 207 Edge weight: 208
# 1 --> 208 Edge weight: 209
# 1 --> 209 Edge weight: 210
# 1 --> 210 Edge weight: 211
# 1 --> 211 Edge weight: 212
# 1 --> 212 Edge weight: 213
# 1 --> 213 Edge weight: 214
# 1 --> 214 Edge weight: 215
# 1 --> 215 Edge weight: 216
# 1 --> 216 Edge weight: 217
# 1 --> 217 Edge weight: 218
# 1 --> 218 Edge weight: 219
# 1 --> 219 Edge weight: 220
# 1 --> 220 Edge weight: 221
# 1 --> 221 Edge weight: 222
# 1 --> 222 Edge weight: 223
# 1 --> 223 Edge weight: 224
# 1 --> 224 Edge weight: 225
# 1 --> 225 Edge weight: 226
# 1 --> 226 Edge weight: 227
# 1 --> 227 Edge weight: 228
# 1 --> 228 Edge weight: 229
# 1 --> 229 Edge weight: 230
# 1 --> 230 Edge weight: 231
# 1 --> 231 Edge weight: 232
# 1 --> 232 Edge weight: 233
# 1 --> 233 Edge weight: 234
# 1 --> 234 Edge weight: 235
# 1 --> 235 Edge weight: 236
# 1 --> 236 Edge weight: 237
# 1 --> 237 Edge weight: 238
# 1 --> 238 Edge weight: 239
# 1 --> 239 Edge weight: 240
# 1 --> 240 Edge weight: 241
# 1 --> 241 Edge weight: 242
# 1 --> 242 Edge weight: 243
# 1 --> 243 Edge weight: 244
# 1 --> 244 Edge weight: 245
# 1 --> 245 Edge weight: 246
# 1 --> 246 Edge weight: 247
# 1 --> 247 Edge weight: 248
# 1 --> 248 Edge weight: 249
# 1 --> 249 Edge weight: 250
# 1 --> 250 Edge weight: 251
# 1 --> 251 Edge weight: 252
# 1 --> 252 Edge weight: 253
# 1 --> 253 Edge weight: 254
# 1 --> 254 Edge weight: 255
# 1 --> 255 Edge weight: 256
# 1 --> 256 Edge weight: 257
# 1 --> 257 Edge weight: 258
# 1 --> 258 Edge weight: 259
# 1 --> 259 Edge weight: 260
# 1 --> 260 Edge weight: 261
# 1 --> 261 Edge weight: 262
# 1 --> 262 Edge weight: 263
# 1 --> 263 Edge weight: 264
# 1 --> 264 Edge weight: 265
# 1 --> 265 Edge weight: 266
# 1 --> 266 Edge weight: 267
# 1 --> 267 Edge weight: 268
# 1 --> 268 Edge weight: 269
# 1 --> 269 Edge weight: 270
# 1 --> 270 Edge weight: 271
# 1 --> 271 Edge weight: 272
# 1 --> 272 Edge weight: 273
# 1 --> 273 Edge weight: 274
# 1 --> 274 Edge weight: 275
# 1 --> 275 Edge weight: 276
# 1 --> 276 Edge weight: 277
# 1 --> 277 Edge weight: 278
# 1 --> 278 Edge weight: 279
# 1 --> 279 Edge weight: 280
# 1 --> 280 Edge weight: 281
# 1 --> 281 Edge weight: 282
# 1 --> 282 Edge weight: 283
# 1 --> 283 Edge weight: 284
# 1 --> 284 Edge weight: 285
# 1 --> 285 Edge weight: 286
# 1 --> 286 Edge weight: 287
# 1 --> 287 Edge weight: 288
# 1 --> 288 Edge weight: 289
# 1 --> 289 Edge weight: 290
# 1 --> 290 Edge weight: 291
# 1 --> 291 Edge weight: 292
# 1 --> 292 Edge weight: 293
# 1 --> 293 Edge weight: 294
# 1 --> 294 Edge weight: 295
# 1 --> 295 Edge weight: 296
# 1 --> 296 Edge weight: 297
# 1 --> 297 Edge weight: 298
# 1 --> 298 Edge weight: 299
# 1 --> 299 Edge weight: 300
# 1 --> 300 Edge weight: 301
# 1 --> 301 Edge weight: 302
# 1 --> 302 Edge weight: 303
# 1 --> 303 Edge weight: 304
# 1 --> 304 Edge weight: 305
# 1 --> 305 Edge weight: 306
# 1 --> 306 Edge weight: 307
# 1 --> 307 Edge weight: 308
# 1 --> 308 Edge weight: 309
# 1 --> 309 Edge weight: 310
# 1 --> 310 Edge weight: 311
# 1 --> 311 Edge weight: 312
# 1 --> 312 Edge weight: 313
# 1 --> 313 Edge weight: 314
# 1 --> 314 Edge weight: 315
# 1 --> 315 Edge weight: 316
# 1 --> 316 Edge weight: 317
# 1 --> 317 Edge weight: 318
# 1 --> 318 Edge weight: 319
# 1 --> 319 Edge weight: 320
# 1 --> 320 Edge weight: 321
# 1 --> 321 Edge weight: 322
# 1 --> 322 Edge weight: 323
# 1 --> 323 Edge weight: 324
# 1 --> 324 Edge weight: 325
# 1 --> 325 Edge weight: 326
# 1 --> 326 Edge weight: 327
# 1 --> 327 Edge weight: 328
# 1 --> 328 Edge weight: 329
# 1 --> 329 Edge weight: 330
# 1 --> 330 Edge weight: 331
# 1 --> 331 Edge weight: 332
# 1 --> 332 Edge weight: 333
# 1 --> 333 Edge weight: 334
# 1 --> 334 Edge weight: 335
# 1 --> 335 Edge weight: 336
# 1 --> 336 Edge weight: 337
# 1 --> 337 Edge weight: 338
# 1 --> 338 Edge weight: 339
# 1 --> 339 Edge weight: 340
# 1 --> 340 Edge weight: 341
# 1 --> 341 Edge weight: 342
# 1 --> 342 Edge weight: 343
# 1 --> 343 Edge weight: 344
# 1 --> 344 Edge weight: 345
# 1 --> 345 Edge weight: 346
# 1 --> 346 Edge weight: 347
# 1 --> 347 Edge weight: 348
# 1 --> 348 Edge weight: 349
# 1 --> 349 Edge weight: 350
# 1 --> 350 Edge weight: 351
# 1 --> 351 Edge weight: 352
# 1 --> 352 Edge weight: 353
# 1 --> 353 Edge weight: 354
# 1 --> 354 Edge weight: 355
# 1 --> 355 Edge weight: 356
# 1 --> 356 Edge weight: 357
# 1 --> 357 Edge weight: 358
# 1 --> 358 Edge weight: 359
# 1 --> 359 Edge weight: 360
# 1 --> 360 Edge weight: 361
# 1 --> 361 Edge weight: 362
# 1 --> 362 Edge weight: 363
# 1 --> 363 Edge weight: 364
# 1 --> 364 Edge weight: 365
# 1 --> 365 Edge weight: 366
# 1 --> 366 Edge weight: 367
# 1 --> 367 Edge weight: 368
# 1 --> 368 Edge weight: 369
# 1 --> 369 Edge weight: 370
# 1 --> 370 Edge weight: 371
# 1 --> 371 Edge weight: 372
# 1 --> 372 Edge weight: 373
# 1 --> 373 Edge weight: 374
# 1 --> 374 Edge weight: 375
# 1 --> 375 Edge weight: 376
# 1 --> 376 Edge weight: 377
# 1 --> 377 Edge weight: 378
# 1 --> 378 Edge weight: 379
# 1 --> 379 Edge weight: 380
# 1 --> 380 Edge weight: 381
# 1 --> 381 Edge weight: 382
# 1 --> 382 Edge weight: 383
# 1 --> 383 Edge weight: 384
# 1 --> 384 Edge weight: 385
# 1 --> 385 Edge weight: 386
# 1 --> 386 Edge weight: 387
# 1 --> 387 Edge weight: 388
# 1 --> 388 Edge weight: 389
# 1 --> 389 Edge weight: 390
# 1 --> 390 Edge weight: 391
# 1 --> 391 Edge weight: 392
# 1 --> 392 Edge weight: 393
# 1 --> 393 Edge weight: 394
# 1 --> 394 Edge weight: 395
# 1 --> 395 Edge weight: 396
# 1 --> 396 Edge weight: 397
# 1 --> 397 Edge weight: 398
# 1 --> 398 Edge weight: 399
# 1 --> 399 Edge weight: 400
# 1 --> 400 Edge weight: 401
# 1 --> 401 Edge weight: 402
# 1 --> 402 Edge weight: 403
# 1 --> 403 Edge weight: 404
# 1 --> 404 Edge weight: 405
# 1 --> 405 Edge weight: 406
# 1 --> 406 Edge weight: 407
# 1 --> 407 Edge weight: 408
# 1 --> 408 Edge weight: 409
# 1 --> 409 Edge weight: 410
# 1 --> 410 Edge weight: 411
# 1 --> 411 Edge weight: 412
# 1 --> 412 Edge weight: 413
# 1 --> 413 Edge weight: 414
# 1 --> 414 Edge weight: 415
# 1 --> 415 Edge weight: 416
# 1 --> 416 Edge weight: 417
# 1 --> 417 Edge weight: 418
# 1 --> 418 Edge weight: 419
# 1 --> 419 Edge weight: 420
# 1 --> 420 Edge weight: 421
# 1 --> 421 Edge weight: 422
# 1 --> 422 Edge weight: 423
# 1 --> 423 Edge weight: 424
# 1 --> 424 Edge weight: 425
# 1 --> 425 Edge weight: 426
# 1 --> 426 Edge weight: 427
# 1 --> 427 Edge weight: 428
# 1 --> 428 Edge weight: 429
# 1 --> 429 Edge weight: 430
# 1 --> 430 Edge weight: 431
# 1 --> 431 Edge weight: 432
# 1 --> 432 Edge weight: 433
# 1 --> 433 Edge weight: 434
# 1 --> 434 Edge weight: 435
# 1 --> 435 Edge weight: 436
# 1 --> 436 Edge weight: 437
# 1 --> 437 Edge weight: 438
# 1 --> 438 Edge weight: 439
# 1 --> 439 Edge weight: 440
# 1 --> 440 Edge weight: 441
# 1 --> 441 Edge weight: 442
# 1 --> 442 Edge weight: 443
# 1 --> 443 Edge weight: 444
# 1 --> 444 Edge weight: 445
# 1 --> 445 Edge weight: 446
# 1 --> 446 Edge weight: 447
# 1 --> 447 Edge weight: 448
# 1 --> 448 Edge weight: 449
# 1 --> 449 Edge weight: 450
# 1 --> 450 Edge weight: 451
# 1 --> 451 Edge weight: 452
# 1 --> 452 Edge weight: 453
# 1 --> 453 Edge weight: 454
# 1 --> 454 Edge weight: 455
# 1 --> 455 Edge weight: 456
# 1 --> 456 Edge weight: 457
# 1 --> 457 Edge weight: 458
# 1 --> 458 Edge weight: 459
# 1 --> 459 Edge weight: 460
# 1 --> 460 Edge weight: 461
# 1 --> 461 Edge weight: 462
# 1 --> 462 Edge weight: 463
# 1 --> 463 Edge weight: 464
# 1 --> 464 Edge weight: 465
# 1 --> 465 Edge weight: 466
# 1 --> 466 Edge weight: 467
# 1 --> 467 Edge weight: 468
# 1 --> 468 Edge weight: 469
# 1 --> 469 Edge weight: 470
# 1 --> 470 Edge weight: 471
# 1 --> 471 Edge weight: 472
# 1 --> 472 Edge weight: 473
# 1 --> 473 Edge weight: 474
# 1 --> 474 Edge weight: 475
# 1 --> 475 Edge weight: 476
# 1 --> 476 Edge weight: 477
# 1 --> 477 Edge weight: 478
# 1 --> 478 Edge weight: 479
# 1 --> 479 Edge weight: 480
# 1 --> 480 Edge weight: 481
# 1 --> 481 Edge weight: 482
# 1 --> 482 Edge weight: 483
# 1 --> 483 Edge weight: 484
# 1 --> 484 Edge weight: 485
# 1 --> 485 Edge weight: 486
# 1 --> 486 Edge weight: 487
# 1 --> 487 Edge weight: 488
# 1 --> 488 Edge weight: 489
# 1 --> 489 Edge weight: 490
# 1 --> 490 Edge weight: 491
# 1 --> 491 Edge weight: 492
# 1 --> 492 Edge weight: 493
# 1 --> 493 Edge weight: 494
# 1 --> 494 Edge weight: 495
# 1 --> 495 Edge weight: 496
# 1 --> 496 Edge weight: 497
# 1 --> 497 Edge weight: 498
# 1 --> 498 Edge weight: 499
# 1 --> 499 Edge weight: 500
# 1 --> 500 Edge weight: 501
# leftNode
# 501 --> 2 Edge weight: 503
# 501 --> 3 Edge weight: 504
# 501 --> 4 Edge weight: 505
# 501 --> 5 Edge weight: 506
# 501 --> 6 Edge weight: 507
# 501 --> 7 Edge weight: 508
# 501 --> 8 Edge weight: 509
# 501 --> 9 Edge weight: 510
# 501 --> 10 Edge weight: 511
# 501 --> 11 Edge weight: 512
# 501 --> 12 Edge weight: 513
# 501 --> 13 Edge weight: 514
# 501 --> 14 Edge weight: 515
# 501 --> 15 Edge weight: 516
# 501 --> 16 Edge weight: 517
# 501 --> 17 Edge weight: 518
# 501 --> 18 Edge weight: 519
# 501 --> 19 Edge weight: 520
# 501 --> 20 Edge weight: 521
# 501 --> 21 Edge weight: 522
# 501 --> 22 Edge weight: 523
# 501 --> 23 Edge weight: 524
# 501 --> 24 Edge weight: 525
# 501 --> 25 Edge weight: 526
# 501 --> 26 Edge weight: 527
# 501 --> 27 Edge weight: 528
# 501 --> 28 Edge weight: 529
# 501 --> 29 Edge weight: 530
# 501 --> 30 Edge weight: 531
# 501 --> 31 Edge weight: 532
# 501 --> 32 Edge weight: 533
# 501 --> 33 Edge weight: 534
# 501 --> 34 Edge weight: 535
# 501 --> 35 Edge weight: 536
# 501 --> 36 Edge weight: 537
# 501 --> 37 Edge weight: 538
# 501 --> 38 Edge weight: 539
# 501 --> 39 Edge weight: 540
# 501 --> 40 Edge weight: 541
# 501 --> 41 Edge weight: 542
# 501 --> 42 Edge weight: 543
# 501 --> 43 Edge weight: 544
# 501 --> 44 Edge weight: 545
# 501 --> 45 Edge weight: 546
# 501 --> 46 Edge weight: 547
# 501 --> 47 Edge weight: 548
# 501 --> 48 Edge weight: 549
# 501 --> 49 Edge weight: 550
# 501 --> 50 Edge weight: 551
# 501 --> 51 Edge weight: 552
# 501 --> 52 Edge weight: 553
# 501 --> 53 Edge weight: 554
# 501 --> 54 Edge weight: 555
# 501 --> 55 Edge weight: 556
# 501 --> 56 Edge weight: 557
# 501 --> 57 Edge weight: 558
# 501 --> 58 Edge weight: 559
# 501 --> 59 Edge weight: 560
# 501 --> 60 Edge weight: 561
# 501 --> 61 Edge weight: 562
# 501 --> 62 Edge weight: 563
# 501 --> 63 Edge weight: 564
# 501 --> 64 Edge weight: 565
# 501 --> 65 Edge weight: 566
# 501 --> 66 Edge weight: 567
# 501 --> 67 Edge weight: 568
# 501 --> 68 Edge weight: 569
# 501 --> 69 Edge weight: 570
# 501 --> 70 Edge weight: 571
# 501 --> 71 Edge weight: 572
# 501 --> 72 Edge weight: 573
# 501 --> 73 Edge weight: 574
# 501 --> 74 Edge weight: 575
# 501 --> 75 Edge weight: 576
# 501 --> 76 Edge weight: 577
# 501 --> 77 Edge weight: 578
# 501 --> 78 Edge weight: 579
# 501 --> 79 Edge weight: 580
# 501 --> 80 Edge weight: 581
# 501 --> 81 Edge weight: 582
# 501 --> 82 Edge weight: 583
# 501 --> 83 Edge weight: 584
# 501 --> 84 Edge weight: 585
# 501 --> 85 Edge weight: 586
# 501 --> 86 Edge weight: 587
# 501 --> 87 Edge weight: 588
# 501 --> 88 Edge weight: 589
# 501 --> 89 Edge weight: 590
# 501 --> 90 Edge weight: 591
# 501 --> 91 Edge weight: 592
# 501 --> 92 Edge weight: 593
# 501 --> 93 Edge weight: 594
# 501 --> 94 Edge weight: 595
# 501 --> 95 Edge weight: 596
# 501 --> 96 Edge weight: 597
# 501 --> 97 Edge weight: 598
# 501 --> 98 Edge weight: 599
# 501 --> 99 Edge weight: 600
# 501 --> 100 Edge weight: 601
# 501 --> 101 Edge weight: 602
# 501 --> 102 Edge weight: 603
# 501 --> 103 Edge weight: 604
# 501 --> 104 Edge weight: 605
# 501 --> 105 Edge weight: 606
# 501 --> 106 Edge weight: 607
# 501 --> 107 Edge weight: 608
# 501 --> 108 Edge weight: 609
# 501 --> 109 Edge weight: 610
# 501 --> 110 Edge weight: 611
# 501 --> 111 Edge weight: 612
# 501 --> 112 Edge weight: 613
# 501 --> 113 Edge weight: 614
# 501 --> 114 Edge weight: 615
# 501 --> 115 Edge weight: 616
# 501 --> 116 Edge weight: 617
# 501 --> 117 Edge weight: 618
# 501 --> 118 Edge weight: 619
# 501 --> 119 Edge weight: 620
# 501 --> 120 Edge weight: 621
# 501 --> 121 Edge weight: 622
# 501 --> 122 Edge weight: 623
# 501 --> 123 Edge weight: 624
# 501 --> 124 Edge weight: 625
# 501 --> 125 Edge weight: 626
# 501 --> 126 Edge weight: 627
# 501 --> 127 Edge weight: 628
# 501 --> 128 Edge weight: 629
# 501 --> 129 Edge weight: 630
# 501 --> 130 Edge weight: 631
# 501 --> 131 Edge weight: 632
# 501 --> 132 Edge weight: 633
# 501 --> 133 Edge weight: 634
# 501 --> 134 Edge weight: 635
# 501 --> 135 Edge weight: 636
# 501 --> 136 Edge weight: 637
# 501 --> 137 Edge weight: 638
# 501 --> 138 Edge weight: 639
# 501 --> 139 Edge weight: 640
# 501 --> 140 Edge weight: 641
# 501 --> 141 Edge weight: 642
# 501 --> 142 Edge weight: 643
# 501 --> 143 Edge weight: 644
# 501 --> 144 Edge weight: 645
# 501 --> 145 Edge weight: 646
# 501 --> 146 Edge weight: 647
# 501 --> 147 Edge weight: 648
# 501 --> 148 Edge weight: 649
# 501 --> 149 Edge weight: 650
# 501 --> 150 Edge weight: 651
# 501 --> 151 Edge weight: 652
# 501 --> 152 Edge weight: 653
# 501 --> 153 Edge weight: 654
# 501 --> 154 Edge weight: 655
# 501 --> 155 Edge weight: 656
# 501 --> 156 Edge weight: 657
# 501 --> 157 Edge weight: 658
# 501 --> 158 Edge weight: 659
# 501 --> 159 Edge weight: 660
# 501 --> 160 Edge weight: 661
# 501 --> 161 Edge weight: 662
# 501 --> 162 Edge weight: 663
# 501 --> 163 Edge weight: 664
# 501 --> 164 Edge weight: 665
# 501 --> 165 Edge weight: 666
# 501 --> 166 Edge weight: 667
# 501 --> 167 Edge weight: 668
# 501 --> 168 Edge weight: 669
# 501 --> 169 Edge weight: 670
# 501 --> 170 Edge weight: 671
# 501 --> 171 Edge weight: 672
# 501 --> 172 Edge weight: 673
# 501 --> 173 Edge weight: 674
# 501 --> 174 Edge weight: 675
# 501 --> 175 Edge weight: 676
# 501 --> 176 Edge weight: 677
# 501 --> 177 Edge weight: 678
# 501 --> 178 Edge weight: 679
# 501 --> 179 Edge weight: 680
# 501 --> 180 Edge weight: 681
# 501 --> 181 Edge weight: 682
# 501 --> 182 Edge weight: 683
# 501 --> 183 Edge weight: 684
# 501 --> 184 Edge weight: 685
# 501 --> 185 Edge weight: 686
# 501 --> 186 Edge weight: 687
# 501 --> 187 Edge weight: 688
# 501 --> 188 Edge weight: 689
# 501 --> 189 Edge weight: 690
# 501 --> 190 Edge weight: 691
# 501 --> 191 Edge weight: 692
# 501 --> 192 Edge weight: 693
# 501 --> 193 Edge weight: 694
# 501 --> 194 Edge weight: 695
# 501 --> 195 Edge weight: 696
# 501 --> 196 Edge weight: 697
# 501 --> 197 Edge weight: 698
# 501 --> 198 Edge weight: 699
# 501 --> 199 Edge weight: 700
# 501 --> 200 Edge weight: 701
# 501 --> 201 Edge weight: 702
# 501 --> 202 Edge weight: 703
# 501 --> 203 Edge weight: 704
# 501 --> 204 Edge weight: 705
# 501 --> 205 Edge weight: 706
# 501 --> 206 Edge weight: 707
# 501 --> 207 Edge weight: 708
# 501 --> 208 Edge weight: 709
# 501 --> 209 Edge weight: 710
# 501 --> 210 Edge weight: 711
# 501 --> 211 Edge weight: 712
# 501 --> 212 Edge weight: 713
# 501 --> 213 Edge weight: 714
# 501 --> 214 Edge weight: 715
# 501 --> 215 Edge weight: 716
# 501 --> 216 Edge weight: 717
# 501 --> 217 Edge weight: 718
# 501 --> 218 Edge weight: 719
# 501 --> 219 Edge weight: 720
# 501 --> 220 Edge weight: 721
# 501 --> 221 Edge weight: 722
# 501 --> 222 Edge weight: 723
# 501 --> 223 Edge weight: 724
# 501 --> 224 Edge weight: 725
# 501 --> 225 Edge weight: 726
# 501 --> 226 Edge weight: 727
# 501 --> 227 Edge weight: 728
# 501 --> 228 Edge weight: 729
# 501 --> 229 Edge weight: 730
# 501 --> 230 Edge weight: 731
# 501 --> 231 Edge weight: 732
# 501 --> 232 Edge weight: 733
# 501 --> 233 Edge weight: 734
# 501 --> 234 Edge weight: 735
# 501 --> 235 Edge weight: 736
# 501 --> 236 Edge weight: 737
# 501 --> 237 Edge weight: 738
# 501 --> 238 Edge weight: 739
# 501 --> 239 Edge weight: 740
# 501 --> 240 Edge weight: 741
# 501 --> 241 Edge weight: 742
# 501 --> 242 Edge weight: 743
# 501 --> 243 Edge weight: 744
# 501 --> 244 Edge weight: 745
# 501 --> 245 Edge weight: 746
# 501 --> 246 Edge weight: 747
# 501 --> 247 Edge weight: 748
# 501 --> 248 Edge weight: 749
# 501 --> 249 Edge weight: 750
# 501 --> 250 Edge weight: 751
# 501 --> 251 Edge weight: 752
# 501 --> 252 Edge weight: 753
# 501 --> 253 Edge weight: 754
# 501 --> 254 Edge weight: 755
# 501 --> 255 Edge weight: 756
# 501 --> 256 Edge weight: 757
# 501 --> 257 Edge weight: 758
# 501 --> 258 Edge weight: 759
# 501 --> 259 Edge weight: 760
# 501 --> 260 Edge weight: 761
# 501 --> 261 Edge weight: 762
# 501 --> 262 Edge weight: 763
# 501 --> 263 Edge weight: 764
# 501 --> 264 Edge weight: 765
# 501 --> 265 Edge weight: 766
# 501 --> 266 Edge weight: 767
# 501 --> 267 Edge weight: 768
# 501 --> 268 Edge weight: 769
# 501 --> 269 Edge weight: 770
# 501 --> 270 Edge weight: 771
# 501 --> 271 Edge weight: 772
# 501 --> 272 Edge weight: 773
# 501 --> 273 Edge weight: 774
# 501 --> 274 Edge weight: 775
# 501 --> 275 Edge weight: 776
# 501 --> 276 Edge weight: 777
# 501 --> 277 Edge weight: 778
# 501 --> 278 Edge weight: 779
# 501 --> 279 Edge weight: 780
# 501 --> 280 Edge weight: 781
# 501 --> 281 Edge weight: 782
# 501 --> 282 Edge weight: 783
# 501 --> 283 Edge weight: 784
# 501 --> 284 Edge weight: 785
# 501 --> 285 Edge weight: 786
# 501 --> 286 Edge weight: 787
# 501 --> 287 Edge weight: 788
# 501 --> 288 Edge weight: 789
# 501 --> 289 Edge weight: 790
# 501 --> 290 Edge weight: 791
# 501 --> 291 Edge weight: 792
# 501 --> 292 Edge weight: 793
# 501 --> 293 Edge weight: 794
# 501 --> 294 Edge weight: 795
# 501 --> 295 Edge weight: 796
# 501 --> 296 Edge weight: 797
# 501 --> 297 Edge weight: 798
# 501 --> 298 Edge weight: 799
# 501 --> 299 Edge weight: 800
# 501 --> 300 Edge weight: 801
# 501 --> 301 Edge weight: 802
# 501 --> 302 Edge weight: 803
# 501 --> 303 Edge weight: 804
# 501 --> 304 Edge weight: 805
# 501 --> 305 Edge weight: 806
# 501 --> 306 Edge weight: 807
# 501 --> 307 Edge weight: 808
# 501 --> 308 Edge weight: 809
# 501 --> 309 Edge weight: 810
# 501 --> 310 Edge weight: 811
# 501 --> 311 Edge weight: 812
# 501 --> 312 Edge weight: 813
# 501 --> 313 Edge weight: 814
# 501 --> 314 Edge weight: 815
# 501 --> 315 Edge weight: 816
# 501 --> 316 Edge weight: 817
# 501 --> 317 Edge weight: 818
# 501 --> 318 Edge weight: 819
# 501 --> 319 Edge weight: 820
# 501 --> 320 Edge weight: 821
# 501 --> 321 Edge weight: 822
# 501 --> 322 Edge weight: 823
# 501 --> 323 Edge weight: 824
# 501 --> 324 Edge weight: 825
# 501 --> 325 Edge weight: 826
# 501 --> 326 Edge weight: 827
# 501 --> 327 Edge weight: 828
# 501 --> 328 Edge weight: 829
# 501 --> 329 Edge weight: 830
# 501 --> 330 Edge weight: 831
# 501 --> 331 Edge weight: 832
# 501 --> 332 Edge weight: 833
# 501 --> 333 Edge weight: 834
# 501 --> 334 Edge weight: 835
# 501 --> 335 Edge weight: 836
# 501 --> 336 Edge weight: 837
# 501 --> 337 Edge weight: 838
# 501 --> 338 Edge weight: 839
# 501 --> 339 Edge weight: 840
# 501 --> 340 Edge weight: 841
# 501 --> 341 Edge weight: 842
# 501 --> 342 Edge weight: 843
# 501 --> 343 Edge weight: 844
# 501 --> 344 Edge weight: 845
# 501 --> 345 Edge weight: 846
# 501 --> 346 Edge weight: 847
# 501 --> 347 Edge weight: 848
# 501 --> 348 Edge weight: 849
# 501 --> 349 Edge weight: 850
# 501 --> 350 Edge weight: 851
# 501 --> 351 Edge weight: 852
# 501 --> 352 Edge weight: 853
# 501 --> 353 Edge weight: 854
# 501 --> 354 Edge weight: 855
# 501 --> 355 Edge weight: 856
# 501 --> 356 Edge weight: 857
# 501 --> 357 Edge weight: 858
# 501 --> 358 Edge weight: 859
# 501 --> 359 Edge weight: 860
# 501 --> 360 Edge weight: 861
# 501 --> 361 Edge weight: 862
# 501 --> 362 Edge weight: 863
# 501 --> 363 Edge weight: 864
# 501 --> 364 Edge weight: 865
# 501 --> 365 Edge weight: 866
# 501 --> 366 Edge weight: 867
# 501 --> 367 Edge weight: 868
# 501 --> 368 Edge weight: 869
# 501 --> 369 Edge weight: 870
# 501 --> 370 Edge weight: 871
# 501 --> 371 Edge weight: 872
# 501 --> 372 Edge weight: 873
# 501 --> 373 Edge weight: 874
# 501 --> 374 Edge weight: 875
# 501 --> 375 Edge weight: 876
# 501 --> 376 Edge weight: 877
# 501 --> 377 Edge weight: 878
# 501 --> 378 Edge weight: 879
# 501 --> 379 Edge weight: 880
# 501 --> 380 Edge weight: 881
# 501 --> 381 Edge weight: 882
# 501 --> 382 Edge weight: 883
# 501 --> 383 Edge weight: 884
# 501 --> 384 Edge weight: 885
# 501 --> 385 Edge weight: 886
# 501 --> 386 Edge weight: 887
# 501 --> 387 Edge weight: 888
# 501 --> 388 Edge weight: 889
# 501 --> 389 Edge weight: 890
# 501 --> 390 Edge weight: 891
# 501 --> 391 Edge weight: 892
# 501 --> 392 Edge weight: 893
# 501 --> 393 Edge weight: 894
# 501 --> 394 Edge weight: 895
# 501 --> 395 Edge weight: 896
# 501 --> 396 Edge weight: 897
# 501 --> 397 Edge weight: 898
# 501 --> 398 Edge weight: 899
# 501 --> 399 Edge weight: 900
# 501 --> 400 Edge weight: 901
# 501 --> 401 Edge weight: 902
# 501 --> 402 Edge weight: 903
# 501 --> 403 Edge weight: 904
# 501 --> 404 Edge weight: 905
# 501 --> 405 Edge weight: 906
# 501 --> 406 Edge weight: 907
# 501 --> 407 Edge weight: 908
# 501 --> 408 Edge weight: 909
# 501 --> 409 Edge weight: 910
# 501 --> 410 Edge weight: 911
# 501 --> 411 Edge weight: 912
# 501 --> 412 Edge weight: 913
# 501 --> 413 Edge weight: 914
# 501 --> 414 Edge weight: 915
# 501 --> 415 Edge weight: 916
# 501 --> 416 Edge weight: 917
# 501 --> 417 Edge weight: 918
# 501 --> 418 Edge weight: 919
# 501 --> 419 Edge weight: 920
# 501 --> 420 Edge weight: 921
# 501 --> 421 Edge weight: 922
# 501 --> 422 Edge weight: 923
# 501 --> 423 Edge weight: 924
# 501 --> 424 Edge weight: 925
# 501 --> 425 Edge weight: 926
# 501 --> 426 Edge weight: 927
# 501 --> 427 Edge weight: 928
# 501 --> 428 Edge weight: 929
# 501 --> 429 Edge weight: 930
# 501 --> 430 Edge weight: 931
# 501 --> 431 Edge weight: 932
# 501 --> 432 Edge weight: 933
# 501 --> 433 Edge weight: 934
# 501 --> 434 Edge weight: 935
# 501 --> 435 Edge weight: 936
# 501 --> 436 Edge weight: 937
# 501 --> 437 Edge weight: 938
# 501 --> 438 Edge weight: 939
# 501 --> 439 Edge weight: 940
# 501 --> 440 Edge weight: 941
# 501 --> 441 Edge weight: 942
# 501 --> 442 Edge weight: 943
# 501 --> 443 Edge weight: 944
# 501 --> 444 Edge weight: 945
# 501 --> 445 Edge weight: 946
# 501 --> 446 Edge weight: 947
# 501 --> 447 Edge weight: 948
# 501 --> 448 Edge weight: 949
# 501 --> 449 Edge weight: 950
# 501 --> 450 Edge weight: 951
# 501 --> 451 Edge weight: 952
# 501 --> 452 Edge weight: 953
# 501 --> 453 Edge weight: 954
# 501 --> 454 Edge weight: 955
# 501 --> 455 Edge weight: 956
# 501 --> 456 Edge weight: 957
# 501 --> 457 Edge weight: 958
# 501 --> 458 Edge weight: 959
# 501 --> 459 Edge weight: 960
# 501 --> 460 Edge weight: 961
# 501 --> 461 Edge weight: 962
# 501 --> 462 Edge weight: 963
# 501 --> 463 Edge weight: 964
# 501 --> 464 Edge weight: 965
# 501 --> 465 Edge weight: 966
# 501 --> 466 Edge weight: 967
# 501 --> 467 Edge weight: 968
# 501 --> 468 Edge weight: 969
# 501 --> 469 Edge weight: 970
# 501 --> 470 Edge weight: 971
# 501 --> 471 Edge weight: 972
# 501 --> 472 Edge weight: 973
# 501 --> 473 Edge weight: 974
# 501 --> 474 Edge weight: 975
# 501 --> 475 Edge weight: 976
# 501 --> 476 Edge weight: 977
# 501 --> 477 Edge weight: 978
# 501 --> 478 Edge weight: 979
# 501 --> 479 Edge weight: 980
# 501 --> 480 Edge weight: 981
# 501 --> 481 Edge weight: 982
# 501 --> 482 Edge weight: 983
# 501 --> 483 Edge weight: 984
# 501 --> 484 Edge weight: 985
# 501 --> 485 Edge weight: 986
# 501 --> 486 Edge weight: 987
# 501 --> 487 Edge weight: 988
# 501 --> 488 Edge weight: 989
# 501 --> 489 Edge weight: 990
# 501 --> 490 Edge weight: 991
# 501 --> 491 Edge weight: 992
# 501 --> 492 Edge weight: 993
# 501 --> 493 Edge weight: 994
# 501 --> 494 Edge weight: 995
# 501 --> 495 Edge weight: 996
# 501 --> 496 Edge weight: 997
# 501 --> 497 Edge weight: 998
# 501 --> 498 Edge weight: 999
# 501 --> 499 Edge weight: 1000
# 501 --> 500 Edge weight: 1001
# centralNode
# 1001 --> 501 Edge weight: 1502 : 1001 --> 1001 Edge weight: 2002
# rightNode
# 501 --> 502 Edge weight: 1003
# 501 --> 503 Edge weight: 1004
# 501 --> 504 Edge weight: 1005
# 501 --> 505 Edge weight: 1006
# 501 --> 506 Edge weight: 1007
# 501 --> 507 Edge weight: 1008
# 501 --> 508 Edge weight: 1009
# 501 --> 509 Edge weight: 1010
# 501 --> 510 Edge weight: 1011
# 501 --> 511 Edge weight: 1012
# 501 --> 512 Edge weight: 1013
# 501 --> 513 Edge weight: 1014
# 501 --> 514 Edge weight: 1015
# 501 --> 515 Edge weight: 1016
# 501 --> 516 Edge weight: 1017
# 501 --> 517 Edge weight: 1018
# 501 --> 518 Edge weight: 1019
# 501 --> 519 Edge weight: 1020
# 501 --> 520 Edge weight: 1021
# 501 --> 521 Edge weight: 1022
# 501 --> 522 Edge weight: 1023
# 501 --> 523 Edge weight: 1024
# 501 --> 524 Edge weight: 1025
# 501 --> 525 Edge weight: 1026
# 501 --> 526 Edge weight: 1027
# 501 --> 527 Edge weight: 1028
# 501 --> 528 Edge weight: 1029
# 501 --> 529 Edge weight: 1030
# 501 --> 530 Edge weight: 1031
# 501 --> 531 Edge weight: 1032
# 501 --> 532 Edge weight: 1033
# 501 --> 533 Edge weight: 1034
# 501 --> 534 Edge weight: 1035
# 501 --> 535 Edge weight: 1036
# 501 --> 536 Edge weight: 1037
# 501 --> 537 Edge weight: 1038
# 501 --> 538 Edge weight: 1039
# 501 --> 539 Edge weight: 1040
# 501 --> 540 Edge weight: 1041
# 501 --> 541 Edge weight: 1042
# 501 --> 542 Edge weight: 1043
# 501 --> 543 Edge weight: 1044
# 501 --> 544 Edge weight: 1045
# 501 --> 545 Edge weight: 1046
# 501 --> 546 Edge weight: 1047
# 501 --> 547 Edge weight: 1048
# 501 --> 548 Edge weight: 1049
# 501 --> 549 Edge weight: 1050
# 501 --> 550 Edge weight: 1051
# 501 --> 551 Edge weight: 1052
# 501 --> 552 Edge weight: 1053
# 501 --> 553 Edge weight: 1054
# 501 --> 554 Edge weight: 1055
# 501 --> 555 Edge weight: 1056
# 501 --> 556 Edge weight: 1057
# 501 --> 557 Edge weight: 1058
# 501 --> 558 Edge weight: 1059
# 501 --> 559 Edge weight: 1060
# 501 --> 560 Edge weight: 1061
# 501 --> 561 Edge weight: 1062
# 501 --> 562 Edge weight: 1063
# 501 --> 563 Edge weight: 1064
# 501 --> 564 Edge weight: 1065
# 501 --> 565 Edge weight: 1066
# 501 --> 566 Edge weight: 1067
# 501 --> 567 Edge weight: 1068
# 501 --> 568 Edge weight: 1069
# 501 --> 569 Edge weight: 1070
# 501 --> 570 Edge weight: 1071
# 501 --> 571 Edge weight: 1072
# 501 --> 572 Edge weight: 1073
# 501 --> 573 Edge weight: 1074
# 501 --> 574 Edge weight: 1075
# 501 --> 575 Edge weight: 1076
# 501 --> 576 Edge weight: 1077
# 501 --> 577 Edge weight: 1078
# 501 --> 578 Edge weight: 1079
# 501 --> 579 Edge weight: 1080
# 501 --> 580 Edge weight: 1081
# 501 --> 581 Edge weight: 1082
# 501 --> 582 Edge weight: 1083
# 501 --> 583 Edge weight: 1084
# 501 --> 584 Edge weight: 1085
# 501 --> 585 Edge weight: 1086
# 501 --> 586 Edge weight: 1087
# 501 --> 587 Edge weight: 1088
# 501 --> 588 Edge weight: 1089
# 501 --> 589 Edge weight: 1090
# 501 --> 590 Edge weight: 1091
# 501 --> 591 Edge weight: 1092
# 501 --> 592 Edge weight: 1093
# 501 --> 593 Edge weight: 1094
# 501 --> 594 Edge weight: 1095
# 501 --> 595 Edge weight: 1096
# 501 --> 596 Edge weight: 1097
# 501 --> 597 Edge weight: 1098
# 501 --> 598 Edge weight: 1099
# 501 --> 599 Edge weight: 1100
# 501 --> 600 Edge weight: 1101
# 501 --> 601 Edge weight: 1102
# 501 --> 602 Edge weight: 1103
# 501 --> 603 Edge weight: 1104
# 501 --> 604 Edge weight: 1105
# 501 --> 605 Edge weight: 1106
# 501 --> 606 Edge weight: 1107
# 501 --> 607 Edge weight: 1108
# 501 --> 608 Edge weight: 1109
# 501 --> 609 Edge weight: 1110
# 501 --> 610 Edge weight: 1111
# 501 --> 611 Edge weight: 1112
# 501 --> 612 Edge weight: 1113
# 501 --> 613 Edge weight: 1114
# 501 --> 614 Edge weight: 1115
# 501 --> 615 Edge weight: 1116
# 501 --> 616 Edge weight: 1117
# 501 --> 617 Edge weight: 1118
# 501 --> 618 Edge weight: 1119
# 501 --> 619 Edge weight: 1120
# 501 --> 620 Edge weight: 1121
# 501 --> 621 Edge weight: 1122
# 501 --> 622 Edge weight: 1123
# 501 --> 623 Edge weight: 1124
# 501 --> 624 Edge weight: 1125
# 501 --> 625 Edge weight: 1126
# 501 --> 626 Edge weight: 1127
# 501 --> 627 Edge weight: 1128
# 501 --> 628 Edge weight: 1129
# 501 --> 629 Edge weight: 1130
# 501 --> 630 Edge weight: 1131
# 501 --> 631 Edge weight: 1132
# 501 --> 632 Edge weight: 1133
# 501 --> 633 Edge weight: 1134
# 501 --> 634 Edge weight: 1135
# 501 --> 635 Edge weight: 1136
# 501 --> 636 Edge weight: 1137
# 501 --> 637 Edge weight: 1138
# 501 --> 638 Edge weight: 1139
# 501 --> 639 Edge weight: 1140
# 501 --> 640 Edge weight: 1141
# 501 --> 641 Edge weight: 1142
# 501 --> 642 Edge weight: 1143
# 501 --> 643 Edge weight: 1144
# 501 --> 644 Edge weight: 1145
# 501 --> 645 Edge weight: 1146
# 501 --> 646 Edge weight: 1147
# 501 --> 647 Edge weight: 1148
# 501 --> 648 Edge weight: 1149
# 501 --> 649 Edge weight: 1150
# 501 --> 650 Edge weight: 1151
# 501 --> 651 Edge weight: 1152
# 501 --> 652 Edge weight: 1153
# 501 --> 653 Edge weight: 1154
# 501 --> 654 Edge weight: 1155
# 501 --> 655 Edge weight: 1156
# 501 --> 656 Edge weight: 1157
# 501 --> 657 Edge weight: 1158
# 501 --> 658 Edge weight: 1159
# 501 --> 659 Edge weight: 1160
# 501 --> 660 Edge weight: 1161
# 501 --> 661 Edge weight: 1162
# 501 --> 662 Edge weight: 1163
# 501 --> 663 Edge weight: 1164
# 501 --> 664 Edge weight: 1165
# 501 --> 665 Edge weight: 1166
# 501 --> 666 Edge weight: 1167
# 501 --> 667 Edge weight: 1168
# 501 --> 668 Edge weight: 1169
# 501 --> 669 Edge weight: 1170
# 501 --> 670 Edge weight: 1171
# 501 --> 671 Edge weight: 1172
# 501 --> 672 Edge weight: 1173
# 501 --> 673 Edge weight: 1174
# 501 --> 674 Edge weight: 1175
# 501 --> 675 Edge weight: 1176
# 501 --> 676 Edge weight: 1177
# 501 --> 677 Edge weight: 1178
# 501 --> 678 Edge weight: 1179
# 501 --> 679 Edge weight: 1180
# 501 --> 680 Edge weight: 1181
# 501 --> 681 Edge weight: 1182
# 501 --> 682 Edge weight: 1183
# 501 --> 683 Edge weight: 1184
# 501 --> 684 Edge weight: 1185
# 501 --> 685 Edge weight: 1186
# 501 --> 686 Edge weight: 1187
# 501 --> 687 Edge weight: 1188
# 501 --> 688 Edge weight: 1189
# 501 --> 689 Edge weight: 1190
# 501 --> 690 Edge weight: 1191
# 501 --> 691 Edge weight: 1192
# 501 --> 692 Edge weight: 1193
# 501 --> 693 Edge weight: 1194
# 501 --> 694 Edge weight: 1195
# 501 --> 695 Edge weight: 1196
# 501 --> 696 Edge weight: 1197
# 501 --> 697 Edge weight: 1198
# 501 --> 698 Edge weight: 1199
# 501 --> 699 Edge weight: 1200
# 501 --> 700 Edge weight: 1201
# 501 --> 701 Edge weight: 1202
# 501 --> 702 Edge weight: 1203
# 501 --> 703 Edge weight: 1204
# 501 --> 704 Edge weight: 1205
# 501 --> 705 Edge weight: 1206
# 501 --> 706 Edge weight: 1207
# 501 --> 707 Edge weight: 1208
# 501 --> 708 Edge weight: 1209
# 501 --> 709 Edge weight: 1210
# 501 --> 710 Edge weight: 1211
# 501 --> 711 Edge weight: 1212
# 501 --> 712 Edge weight: 1213
# 501 --> 713 Edge weight: 1214
# 501 --> 714 Edge weight: 1215
# 501 --> 715 Edge weight: 1216
# 501 --> 716 Edge weight: 1217
# 501 --> 717 Edge weight: 1218
# 501 --> 718 Edge weight: 1219
# 501 --> 719 Edge weight: 1220
# 501 --> 720 Edge weight: 1221
# 501 --> 721 Edge weight: 1222
# 501 --> 722 Edge weight: 1223
# 501 --> 723 Edge weight: 1224
# 501 --> 724 Edge weight: 1225
# 501 --> 725 Edge weight: 1226
# 501 --> 726 Edge weight: 1227
# 501 --> 727 Edge weight: 1228
# 501 --> 728 Edge weight: 1229
# 501 --> 729 Edge weight: 1230
# 501 --> 730 Edge weight: 1231
# 501 --> 731 Edge weight: 1232
# 501 --> 732 Edge weight: 1233
# 501 --> 733 Edge weight: 1234
# 501 --> 734 Edge weight: 1235
# 501 --> 735 Edge weight: 1236
# 501 --> 736 Edge weight: 1237
# 501 --> 737 Edge weight: 1238
# 501 --> 738 Edge weight: 1239
# 501 --> 739 Edge weight: 1240
# 501 --> 740 Edge weight: 1241
# 501 --> 741 Edge weight: 1242
# 501 --> 742 Edge weight: 1243
# 501 --> 743 Edge weight: 1244
# 501 --> 744 Edge weight: 1245
# 501 --> 745 Edge weight: 1246
# 501 --> 746 Edge weight: 1247
# 501 --> 747 Edge weight: 1248
# 501 --> 748 Edge weight: 1249
# 501 --> 749 Edge weight: 1250
# 501 --> 750 Edge weight: 1251
# 501 --> 751 Edge weight: 1252
# 501 --> 752 Edge weight: 1253
# 501 --> 753 Edge weight: 1254
# 501 --> 754 Edge weight: 1255
# 501 --> 755 Edge weight: 1256
# 501 --> 756 Edge weight: 1257
# 501 --> 757 Edge weight: 1258
# 501 --> 758 Edge weight: 1259
# 501 --> 759 Edge weight: 1260
# 501 --> 760 Edge weight: 1261
# 501 --> 761 Edge weight: 1262
# 501 --> 762 Edge weight: 1263
# 501 --> 763 Edge weight: 1264
# 501 --> 764 Edge weight: 1265
# 501 --> 765 Edge weight: 1266
# 501 --> 766 Edge weight: 1267
# 501 --> 767 Edge weight: 1268
# 501 --> 768 Edge weight: 1269
# 501 --> 769 Edge weight: 1270
# 501 --> 770 Edge weight: 1271
# 501 --> 771 Edge weight: 1272
# 501 --> 772 Edge weight: 1273
# 501 --> 773 Edge weight: 1274
# 501 --> 774 Edge weight: 1275
# 501 --> 775 Edge weight: 1276
# 501 --> 776 Edge weight: 1277
# 501 --> 777 Edge weight: 1278
# 501 --> 778 Edge weight: 1279
# 501 --> 779 Edge weight: 1280
# 501 --> 780 Edge weight: 1281
# 501 --> 781 Edge weight: 1282
# 501 --> 782 Edge weight: 1283
# 501 --> 783 Edge weight: 1284
# 501 --> 784 Edge weight: 1285
# 501 --> 785 Edge weight: 1286
# 501 --> 786 Edge weight: 1287
# 501 --> 787 Edge weight: 1288
# 501 --> 788 Edge weight: 1289
# 501 --> 789 Edge weight: 1290
# 501 --> 790 Edge weight: 1291
# 501 --> 791 Edge weight: 1292
# 501 --> 792 Edge weight: 1293
# 501 --> 793 Edge weight: 1294
# 501 --> 794 Edge weight: 1295
# 501 --> 795 Edge weight: 1296
# 501 --> 796 Edge weight: 1297
# 501 --> 797 Edge weight: 1298
# 501 --> 798 Edge weight: 1299
# 501 --> 799 Edge weight: 1300
# 501 --> 800 Edge weight: 1301
# 501 --> 801 Edge weight: 1302
# 501 --> 802 Edge weight: 1303
# 501 --> 803 Edge weight: 1304
# 501 --> 804 Edge weight: 1305
# 501 --> 805 Edge weight: 1306
# 501 --> 806 Edge weight: 1307
# 501 --> 807 Edge weight: 1308
# 501 --> 808 Edge weight: 1309
# 501 --> 809 Edge weight: 1310
# 501 --> 810 Edge weight: 1311
# 501 --> 811 Edge weight: 1312
# 501 --> 812 Edge weight: 1313
# 501 --> 813 Edge weight: 1314
# 501 --> 814 Edge weight: 1315
# 501 --> 815 Edge weight: 1316
# 501 --> 816 Edge weight: 1317
# 501 --> 817 Edge weight: 1318
# 501 --> 818 Edge weight: 1319
# 501 --> 819 Edge weight: 1320
# 501 --> 820 Edge weight: 1321
# 501 --> 821 Edge weight: 1322
# 501 --> 822 Edge weight: 1323
# 501 --> 823 Edge weight: 1324
# 501 --> 824 Edge weight: 1325
# 501 --> 825 Edge weight: 1326
# 501 --> 826 Edge weight: 1327
# 501 --> 827 Edge weight: 1328
# 501 --> 828 Edge weight: 1329
# 501 --> 829 Edge weight: 1330
# 501 --> 830 Edge weight: 1331
# 501 --> 831 Edge weight: 1332
# 501 --> 832 Edge weight: 1333
# 501 --> 833 Edge weight: 1334
# 501 --> 834 Edge weight: 1335
# 501 --> 835 Edge weight: 1336
# 501 --> 836 Edge weight: 1337
# 501 --> 837 Edge weight: 1338
# 501 --> 838 Edge weight: 1339
# 501 --> 839 Edge weight: 1340
# 501 --> 840 Edge weight: 1341
# 501 --> 841 Edge weight: 1342
# 501 --> 842 Edge weight: 1343
# 501 --> 843 Edge weight: 1344
# 501 --> 844 Edge weight: 1345
# 501 --> 845 Edge weight: 1346
# 501 --> 846 Edge weight: 1347
# 501 --> 847 Edge weight: 1348
# 501 --> 848 Edge weight: 1349
# 501 --> 849 Edge weight: 1350
# 501 --> 850 Edge weight: 1351
# 501 --> 851 Edge weight: 1352
# 501 --> 852 Edge weight: 1353
# 501 --> 853 Edge weight: 1354
# 501 --> 854 Edge weight: 1355
# 501 --> 855 Edge weight: 1356
# 501 --> 856 Edge weight: 1357
# 501 --> 857 Edge weight: 1358
# 501 --> 858 Edge weight: 1359
# 501 --> 859 Edge weight: 1360
# 501 --> 860 Edge weight: 1361
# 501 --> 861 Edge weight: 1362
# 501 --> 862 Edge weight: 1363
# 501 --> 863 Edge weight: 1364
# 501 --> 864 Edge weight: 1365
# 501 --> 865 Edge weight: 1366
# 501 --> 866 Edge weight: 1367
# 501 --> 867 Edge weight: 1368
# 501 --> 868 Edge weight: 1369
# 501 --> 869 Edge weight: 1370
# 501 --> 870 Edge weight: 1371
# 501 --> 871 Edge weight: 1372
# 501 --> 872 Edge weight: 1373
# 501 --> 873 Edge weight: 1374
# 501 --> 874 Edge weight: 1375
# 501 --> 875 Edge weight: 1376
# 501 --> 876 Edge weight: 1377
# 501 --> 877 Edge weight: 1378
# 501 --> 878 Edge weight: 1379
# 501 --> 879 Edge weight: 1380
# 501 --> 880 Edge weight: 1381
# 501 --> 881 Edge weight: 1382
# 501 --> 882 Edge weight: 1383
# 501 --> 883 Edge weight: 1384
# 501 --> 884 Edge weight: 1385
# 501 --> 885 Edge weight: 1386
# 501 --> 886 Edge weight: 1387
# 501 --> 887 Edge weight: 1388
# 501 --> 888 Edge weight: 1389
# 501 --> 889 Edge weight: 1390
# 501 --> 890 Edge weight: 1391
# 501 --> 891 Edge weight: 1392
# 501 --> 892 Edge weight: 1393
# 501 --> 893 Edge weight: 1394
# 501 --> 894 Edge weight: 1395
# 501 --> 895 Edge weight: 1396
# 501 --> 896 Edge weight: 1397
# 501 --> 897 Edge weight: 1398
# 501 --> 898 Edge weight: 1399
# 501 --> 899 Edge weight: 1400
# 501 --> 900 Edge weight: 1401
# 501 --> 901 Edge weight: 1402
# 501 --> 902 Edge weight: 1403
# 501 --> 903 Edge weight: 1404
# 501 --> 904 Edge weight: 1405
# 501 --> 905 Edge weight: 1406
# 501 --> 906 Edge weight: 1407
# 501 --> 907 Edge weight: 1408
# 501 --> 908 Edge weight: 1409
# 501 --> 909 Edge weight: 1410
# 501 --> 910 Edge weight: 1411
# 501 --> 911 Edge weight: 1412
# 501 --> 912 Edge weight: 1413
# 501 --> 913 Edge weight: 1414
# 501 --> 914 Edge weight: 1415
# 501 --> 915 Edge weight: 1416
# 501 --> 916 Edge weight: 1417
# 501 --> 917 Edge weight: 1418
# 501 --> 918 Edge weight: 1419
# 501 --> 919 Edge weight: 1420
# 501 --> 920 Edge weight: 1421
# 501 --> 921 Edge weight: 1422
# 501 --> 922 Edge weight: 1423
# 501 --> 923 Edge weight: 1424
# 501 --> 924 Edge weight: 1425
# 501 --> 925 Edge weight: 1426
# 501 --> 926 Edge weight: 1427
# 501 --> 927 Edge weight: 1428
# 501 --> 928 Edge weight: 1429
# 501 --> 929 Edge weight: 1430
# 501 --> 930 Edge weight: 1431
# 501 --> 931 Edge weight: 1432
# 501 --> 932 Edge weight: 1433
# 501 --> 933 Edge weight: 1434
# 501 --> 934 Edge weight: 1435
# 501 --> 935 Edge weight: 1436
# 501 --> 936 Edge weight: 1437
# 501 --> 937 Edge weight: 1438
# 501 --> 938 Edge weight: 1439
# 501 --> 939 Edge weight: 1440
# 501 --> 940 Edge weight: 1441
# 501 --> 941 Edge weight: 1442
# 501 --> 942 Edge weight: 1443
# 501 --> 943 Edge weight: 1444
# 501 --> 944 Edge weight: 1445
# 501 --> 945 Edge weight: 1446
# 501 --> 946 Edge weight: 1447
# 501 --> 947 Edge weight: 1448
# 501 --> 948 Edge weight: 1449
# 501 --> 949 Edge weight: 1450
# 501 --> 950 Edge weight: 1451
# 501 --> 951 Edge weight: 1452
# 501 --> 952 Edge weight: 1453
# 501 --> 953 Edge weight: 1454
# 501 --> 954 Edge weight: 1455
# 501 --> 955 Edge weight: 1456
# 501 --> 956 Edge weight: 1457
# 501 --> 957 Edge weight: 1458
# 501 --> 958 Edge weight: 1459
# 501 --> 959 Edge weight: 1460
# 501 --> 960 Edge weight: 1461
# 501 --> 961 Edge weight: 1462
# 501 --> 962 Edge weight: 1463
# 501 --> 963 Edge weight: 1464
# 501 --> 964 Edge weight: 1465
# 501 --> 965 Edge weight: 1466
# 501 --> 966 Edge weight: 1467
# 501 --> 967 Edge weight: 1468
# 501 --> 968 Edge weight: 1469
# 501 --> 969 Edge weight: 1470
# 501 --> 970 Edge weight: 1471
# 501 --> 971 Edge weight: 1472
# 501 --> 972 Edge weight: 1473
# 501 --> 973 Edge weight: 1474
# 501 --> 974 Edge weight: 1475
# 501 --> 975 Edge weight: 1476
# 501 --> 976 Edge weight: 1477
# 501 --> 977 Edge weight: 1478
# 501 --> 978 Edge weight: 1479
# 501 --> 979 Edge weight: 1480
# 501 --> 980 Edge weight: 1481
# 501 --> 981 Edge weight: 1482
# 501 --> 982 Edge weight: 1483
# 501 --> 983 Edge weight: 1484
# 501 --> 984 Edge weight: 1485
# 501 --> 985 Edge weight: 1486
# 501 --> 986 Edge weight: 1487
# 501 --> 987 Edge weight: 1488
# 501 --> 988 Edge weight: 1489
# 501 --> 989 Edge weight: 1490
# 501 --> 990 Edge weight: 1491
# 501 --> 991 Edge weight: 1492
# 501 --> 992 Edge weight: 1493
# 501 --> 993 Edge weight: 1494
# 501 --> 994 Edge weight: 1495
# 501 --> 995 Edge weight: 1496
# 501 --> 996 Edge weight: 1497
# 501 --> 997 Edge weight: 1498
# 501 --> 998 Edge weight: 1499
# 501 --> 999 Edge weight: 1500
# 501 --> 1000 Edge weight: 1501
# leftNode
# 1001 --> 502 Edge weight: 1503
# 1001 --> 503 Edge weight: 1504
# 1001 --> 504 Edge weight: 1505
# 1001 --> 505 Edge weight: 1506
# 1001 --> 506 Edge weight: 1507
# 1001 --> 507 Edge weight: 1508
# 1001 --> 508 Edge weight: 1509
# 1001 --> 509 Edge weight: 1510
# 1001 --> 510 Edge weight: 1511
# 1001 --> 511 Edge weight: 1512
# 1001 --> 512 Edge weight: 1513
# 1001 --> 513 Edge weight: 1514
# 1001 --> 514 Edge weight: 1515
# 1001 --> 515 Edge weight: 1516
# 1001 --> 516 Edge weight: 1517
# 1001 --> 517 Edge weight: 1518
# 1001 --> 518 Edge weight: 1519
# 1001 --> 519 Edge weight: 1520
# 1001 --> 520 Edge weight: 1521
# 1001 --> 521 Edge weight: 1522
# 1001 --> 522 Edge weight: 1523
# 1001 --> 523 Edge weight: 1524
# 1001 --> 524 Edge weight: 1525
# 1001 --> 525 Edge weight: 1526
# 1001 --> 526 Edge weight: 1527
# 1001 --> 527 Edge weight: 1528
# 1001 --> 528 Edge weight: 1529
# 1001 --> 529 Edge weight: 1530
# 1001 --> 530 Edge weight: 1531
# 1001 --> 531 Edge weight: 1532
# 1001 --> 532 Edge weight: 1533
# 1001 --> 533 Edge weight: 1534
# 1001 --> 534 Edge weight: 1535
# 1001 --> 535 Edge weight: 1536
# 1001 --> 536 Edge weight: 1537
# 1001 --> 537 Edge weight: 1538
# 1001 --> 538 Edge weight: 1539
# 1001 --> 539 Edge weight: 1540
# 1001 --> 540 Edge weight: 1541
# 1001 --> 541 Edge weight: 1542
# 1001 --> 542 Edge weight: 1543
# 1001 --> 543 Edge weight: 1544
# 1001 --> 544 Edge weight: 1545
# 1001 --> 545 Edge weight: 1546
# 1001 --> 546 Edge weight: 1547
# 1001 --> 547 Edge weight: 1548
# 1001 --> 548 Edge weight: 1549
# 1001 --> 549 Edge weight: 1550
# 1001 --> 550 Edge weight: 1551
# 1001 --> 551 Edge weight: 1552
# 1001 --> 552 Edge weight: 1553
# 1001 --> 553 Edge weight: 1554
# 1001 --> 554 Edge weight: 1555
# 1001 --> 555 Edge weight: 1556
# 1001 --> 556 Edge weight: 1557
# 1001 --> 557 Edge weight: 1558
# 1001 --> 558 Edge weight: 1559
# 1001 --> 559 Edge weight: 1560
# 1001 --> 560 Edge weight: 1561
# 1001 --> 561 Edge weight: 1562
# 1001 --> 562 Edge weight: 1563
# 1001 --> 563 Edge weight: 1564
# 1001 --> 564 Edge weight: 1565
# 1001 --> 565 Edge weight: 1566
# 1001 --> 566 Edge weight: 1567
# 1001 --> 567 Edge weight: 1568
# 1001 --> 568 Edge weight: 1569
# 1001 --> 569 Edge weight: 1570
# 1001 --> 570 Edge weight: 1571
# 1001 --> 571 Edge weight: 1572
# 1001 --> 572 Edge weight: 1573
# 1001 --> 573 Edge weight: 1574
# 1001 --> 574 Edge weight: 1575
# 1001 --> 575 Edge weight: 1576
# 1001 --> 576 Edge weight: 1577
# 1001 --> 577 Edge weight: 1578
# 1001 --> 578 Edge weight: 1579
# 1001 --> 579 Edge weight: 1580
# 1001 --> 580 Edge weight: 1581
# 1001 --> 581 Edge weight: 1582
# 1001 --> 582 Edge weight: 1583
# 1001 --> 583 Edge weight: 1584
# 1001 --> 584 Edge weight: 1585
# 1001 --> 585 Edge weight: 1586
# 1001 --> 586 Edge weight: 1587
# 1001 --> 587 Edge weight: 1588
# 1001 --> 588 Edge weight: 1589
# 1001 --> 589 Edge weight: 1590
# 1001 --> 590 Edge weight: 1591
# 1001 --> 591 Edge weight: 1592
# 1001 --> 592 Edge weight: 1593
# 1001 --> 593 Edge weight: 1594
# 1001 --> 594 Edge weight: 1595
# 1001 --> 595 Edge weight: 1596
# 1001 --> 596 Edge weight: 1597
# 1001 --> 597 Edge weight: 1598
# 1001 --> 598 Edge weight: 1599
# 1001 --> 599 Edge weight: 1600
# 1001 --> 600 Edge weight: 1601
# 1001 --> 601 Edge weight: 1602
# 1001 --> 602 Edge weight: 1603
# 1001 --> 603 Edge weight: 1604
# 1001 --> 604 Edge weight: 1605
# 1001 --> 605 Edge weight: 1606
# 1001 --> 606 Edge weight: 1607
# 1001 --> 607 Edge weight: 1608
# 1001 --> 608 Edge weight: 1609
# 1001 --> 609 Edge weight: 1610
# 1001 --> 610 Edge weight: 1611
# 1001 --> 611 Edge weight: 1612
# 1001 --> 612 Edge weight: 1613
# 1001 --> 613 Edge weight: 1614
# 1001 --> 614 Edge weight: 1615
# 1001 --> 615 Edge weight: 1616
# 1001 --> 616 Edge weight: 1617
# 1001 --> 617 Edge weight: 1618
# 1001 --> 618 Edge weight: 1619
# 1001 --> 619 Edge weight: 1620
# 1001 --> 620 Edge weight: 1621
# 1001 --> 621 Edge weight: 1622
# 1001 --> 622 Edge weight: 1623
# 1001 --> 623 Edge weight: 1624
# 1001 --> 624 Edge weight: 1625
# 1001 --> 625 Edge weight: 1626
# 1001 --> 626 Edge weight: 1627
# 1001 --> 627 Edge weight: 1628
# 1001 --> 628 Edge weight: 1629
# 1001 --> 629 Edge weight: 1630
# 1001 --> 630 Edge weight: 1631
# 1001 --> 631 Edge weight: 1632
# 1001 --> 632 Edge weight: 1633
# 1001 --> 633 Edge weight: 1634
# 1001 --> 634 Edge weight: 1635
# 1001 --> 635 Edge weight: 1636
# 1001 --> 636 Edge weight: 1637
# 1001 --> 637 Edge weight: 1638
# 1001 --> 638 Edge weight: 1639
# 1001 --> 639 Edge weight: 1640
# 1001 --> 640 Edge weight: 1641
# 1001 --> 641 Edge weight: 1642
# 1001 --> 642 Edge weight: 1643
# 1001 --> 643 Edge weight: 1644
# 1001 --> 644 Edge weight: 1645
# 1001 --> 645 Edge weight: 1646
# 1001 --> 646 Edge weight: 1647
# 1001 --> 647 Edge weight: 1648
# 1001 --> 648 Edge weight: 1649
# 1001 --> 649 Edge weight: 1650
# 1001 --> 650 Edge weight: 1651
# 1001 --> 651 Edge weight: 1652
# 1001 --> 652 Edge weight: 1653
# 1001 --> 653 Edge weight: 1654
# 1001 --> 654 Edge weight: 1655
# 1001 --> 655 Edge weight: 1656
# 1001 --> 656 Edge weight: 1657
# 1001 --> 657 Edge weight: 1658
# 1001 --> 658 Edge weight: 1659
# 1001 --> 659 Edge weight: 1660
# 1001 --> 660 Edge weight: 1661
# 1001 --> 661 Edge weight: 1662
# 1001 --> 662 Edge weight: 1663
# 1001 --> 663 Edge weight: 1664
# 1001 --> 664 Edge weight: 1665
# 1001 --> 665 Edge weight: 1666
# 1001 --> 666 Edge weight: 1667
# 1001 --> 667 Edge weight: 1668
# 1001 --> 668 Edge weight: 1669
# ...
# 26527 --> 26692 Edge weight: 53219
# 26527 --> 26693 Edge weight: 53220
# 26527 --> 26694 Edge weight: 53221
# 26527 --> 26695 Edge weight: 53222
# 26527 --> 26696 Edge weight: 53223
# 26527 --> 26697 Edge weight: 53224
# 26527 --> 26698 Edge weight: 53225
# 26527 --> 26699 Edge weight: 53226
# 26527 --> 26700 Edge weight: 53227
# 26527 --> 26701 Edge weight: 53228
# 26527 --> 26702 Edge weight: 53229
# 26527 --> 26703 Edge weight: 53230
# 26527 --> 26704 Edge weight: 53231
# 26527 --> 26705 Edge weight: 53232
# 26527 --> 26706 Edge weight: 53233
# 26527 --> 26707 Edge weight: 53234
# 26527 --> 26708 Edge weight: 53235
# 26527 --> 26709 Edge weight: 53236
# 26527 --> 26710 Edge weight: 53237
# 26527 --> 26711 Edge weight: 53238
# 26527 --> 26712 Edge weight: 53239
# 26527 --> 26713 Edge weight: 53240
# 26527 --> 26714 Edge weight: 53241
# 26527 --> 26715 Edge weight: 53242
# 26527 --> 26716 Edge weight: 53243
# 26527 --> 26717 Edge weight: 53244
# 26527 --> 26718 Edge weight: 53245
# 26527 --> 26719 Edge weight: 53246
# 26527 --> 26720 Edge weight: 53247
# 26527 --> 26721 Edge weight: 53248
# 26527 --> 26722 Edge weight: 53249
# 26527 --> 26723 Edge weight: 53250
# 26527 --> 26724 Edge weight: 53251
# 26527 --> 26725 Edge weight: 53252
# 26527 --> 26726 Edge weight: 53253
# 26527 --> 26727 Edge weight: 53254
# 26527 --> 26728 Edge weight: 53255
# 26527 --> 26729 Edge weight: 53256
# 26527 --> 26730 Edge weight: 53257
# 26527 --> 26731 Edge weight: 53258
# 26527 --> 26732 Edge weight: 53259
# 26527 --> 26733 Edge weight: 53260
# 26527 --> 26734 Edge weight: 53261
# 26527 --> 26735 Edge weight: 53262
# 26527 --> 26736 Edge weight: 53263
# 26527 --> 26737 Edge weight: 53264
# 26527 --> 26738 Edge weight: 53265
# 26527 --> 26739 Edge weight: 53266
# 26527 --> 26740 Edge weight: 53267
# 26527 --> 26741 Edge weight: 53268
# 26527 --> 26742 Edge weight: 53269
# 26527 --> 26743 Edge weight: 53270
# 26527 --> 26744 Edge weight: 53271
# 26527 --> 26745 Edge weight: 53272
# 26527 --> 26746 Edge weight: 53273
# 26527 --> 26747 Edge weight: 53274
# 26527 --> 26748 Edge weight: 53275
# 26527 --> 26749 Edge weight: 53276
# 26527 --> 26750 Edge weight: 53277
# 26527 --> 26751 Edge weight: 53278
# 26527 --> 26752 Edge weight: 53279
# 26527 --> 26753 Edge weight: 53280
# 26527 --> 26754 Edge weight: 53281
# 26527 --> 26755 Edge weight: 53282
# 26527 --> 26756 Edge weight: 53283
# 26527 --> 26757 Edge weight: 53284
# 26527 --> 26758 Edge weight: 53285
# 26527 --> 26759 Edge weight: 53286
# 26527 --> 26760 Edge weight: 53287
# 26527 --> 26761 Edge weight: 53288
# 26527 --> 26762 Edge weight: 53289
# 26527 --> 26763 Edge weight: 53290
# 26527 --> 26764 Edge weight: 53291
# 26527 --> 26765 Edge weight: 53292
# 26527 --> 26766 Edge weight: 53293
# 26527 --> 26767 Edge weight: 53294
# 26527 --> 26768 Edge weight: 53295
# 26527 --> 26769 Edge weight: 53296
# 26527 --> 26770 Edge weight: 53297
# 26527 --> 26771 Edge weight: 53298
# 26527 --> 26772 Edge weight: 53299
# 26527 --> 26773 Edge weight: 53300
# 26527 --> 26774 Edge weight: 53301
# 26527 --> 26775 Edge weight: 53302
# 26527 --> 26776 Edge weight: 53303
# 26527 --> 26777 Edge weight: 53304
# 26527 --> 26778 Edge weight: 53305
# 26527 --> 26779 Edge weight: 53306
# 26527 --> 26780 Edge weight: 53307
# 26527 --> 26781 Edge weight: 53308
# 26527 --> 26782 Edge weight: 53309
# 26527 --> 26783 Edge weight: 53310
# 26527 --> 26784 Edge weight: 53311
# 26527 --> 26785 Edge weight: 53312
# 26527 --> 26786 Edge weight: 53313
# 26527 --> 26787 Edge weight: 53314
# 26527 --> 26788 Edge weight: 53315
# 26527 --> 26789 Edge weight: 53316
# 26527 --> 26790 Edge weight: 53317
# 26527 --> 26791 Edge weight: 53318
# 26527 --> 26792 Edge weight: 53319
# 26527 --> 26793 Edge weight: 53320
# 26527 --> 26794 Edge weight: 53321
# 26527 --> 26795 Edge weight: 53322
# 26527 --> 26796 Edge weight: 53323
# 26527 --> 26797 Edge weight: 53324
# 26527 --> 26798 Edge weight: 53325
# 26527 --> 26799 Edge weight: 53326
# 26527 --> 26800 Edge weight: 53327
# 26527 --> 26801 Edge weight: 53328
# 26527 --> 26802 Edge weight: 53329
# 26527 --> 26803 Edge weight: 53330
# 26527 --> 26804 Edge weight: 53331
# 26527 --> 26805 Edge weight: 53332
# 26527 --> 26806 Edge weight: 53333
# 26527 --> 26807 Edge weight: 53334
# 26527 --> 26808 Edge weight: 53335
# 26527 --> 26809 Edge weight: 53336
# 26527 --> 26810 Edge weight: 53337
# 26527 --> 26811 Edge weight: 53338
# 26527 --> 26812 Edge weight: 53339
# 26527 --> 26813 Edge weight: 53340
# 26527 --> 26814 Edge weight: 53341
# 26527 --> 26815 Edge weight: 53342
# 26527 --> 26816 Edge weight: 53343
# 26527 --> 26817 Edge weight: 53344
# 26527 --> 26818 Edge weight: 53345
# 26527 --> 26819 Edge weight: 53346
# 26527 --> 26820 Edge weight: 53347
# 26527 --> 26821 Edge weight: 53348
# 26527 --> 26822 Edge weight: 53349
# 26527 --> 26823 Edge weight: 53350
# 26527 --> 26824 Edge weight: 53351
# 26527 --> 26825 Edge weight: 53352
# 26527 --> 26826 Edge weight: 53353
# 26527 --> 26827 Edge weight: 53354
# 26527 --> 26828 Edge weight: 53355
# 26527 --> 26829 Edge weight: 53356
# 26527 --> 26830 Edge weight: 53357
# 26527 --> 26831 Edge weight: 53358
# 26527 --> 26832 Edge weight: 53359
# 26527 --> 26833 Edge weight: 53360
# 26527 --> 26834 Edge weight: 53361
# 26527 --> 26835 Edge weight: 53362
# 26527 --> 26836 Edge weight: 53363
# 26527 --> 26837 Edge weight: 53364
# 26527 --> 26838 Edge weight: 53365
# 26527 --> 26839 Edge weight: 53366
# 26527 --> 26840 Edge weight: 53367
# 26527 --> 26841 Edge weight: 53368
# 26527 --> 26842 Edge weight: 53369
# 26527 --> 26843 Edge weight: 53370
# 26527 --> 26844 Edge weight: 53371
# 26527 --> 26845 Edge weight: 53372
# 26527 --> 26846 Edge weight: 53373
# 26527 --> 26847 Edge weight: 53374
# 26527 --> 26848 Edge weight: 53375
# 26527 --> 26849 Edge weight: 53376
# 26527 --> 26850 Edge weight: 53377
# 26527 --> 26851 Edge weight: 53378
# 26527 --> 26852 Edge weight: 53379
# 26527 --> 26853 Edge weight: 53380
# 26527 --> 26854 Edge weight: 53381
# 26527 --> 26855 Edge weight: 53382
# 26527 --> 26856 Edge weight: 53383
# 26527 --> 26857 Edge weight: 53384
# 26527 --> 26858 Edge weight: 53385
# 26527 --> 26859 Edge weight: 53386
# 26527 --> 26860 Edge weight: 53387
# 26527 --> 26861 Edge weight: 53388
# 26527 --> 26862 Edge weight: 53389
# 26527 --> 26863 Edge weight: 53390
# 26527 --> 26864 Edge weight: 53391
# 26527 --> 26865 Edge weight: 53392
# 26527 --> 26866 Edge weight: 53393
# 26527 --> 26867 Edge weight: 53394
# 26527 --> 26868 Edge weight: 53395
# 26527 --> 26869 Edge weight: 53396
# 26527 --> 26870 Edge weight: 53397
# 26527 --> 26871 Edge weight: 53398
# 26527 --> 26872 Edge weight: 53399
# 26527 --> 26873 Edge weight: 53400
# 26527 --> 26874 Edge weight: 53401
# 26527 --> 26875 Edge weight: 53402
# 26527 --> 26876 Edge weight: 53403
# 26527 --> 26877 Edge weight: 53404
# 26527 --> 26878 Edge weight: 53405
# 26527 --> 26879 Edge weight: 53406
# 26527 --> 26880 Edge weight: 53407
# 26527 --> 26881 Edge weight: 53408
# 26527 --> 26882 Edge weight: 53409
# 26527 --> 26883 Edge weight: 53410
# 26527 --> 26884 Edge weight: 53411
# 26527 --> 26885 Edge weight: 53412
# 26527 --> 26886 Edge weight: 53413
# 26527 --> 26887 Edge weight: 53414
# 26527 --> 26888 Edge weight: 53415
# 26527 --> 26889 Edge weight: 53416
# 26527 --> 26890 Edge weight: 53417
# 26527 --> 26891 Edge weight: 53418
# 26527 --> 26892 Edge weight: 53419
# 26527 --> 26893 Edge weight: 53420
# 26527 --> 26894 Edge weight: 53421
# 26527 --> 26895 Edge weight: 53422
# 26527 --> 26896 Edge weight: 53423
# 26527 --> 26897 Edge weight: 53424
# 26527 --> 26898 Edge weight: 53425
# 26527 --> 26899 Edge weight: 53426
# 26527 --> 26900 Edge weight: 53427
# 26527 --> 26901 Edge weight: 53428
# 26527 --> 26902 Edge weight: 53429
# 26527 --> 26903 Edge weight: 53430
# 26527 --> 26904 Edge weight: 53431
# 26527 --> 26905 Edge weight: 53432
# 26527 --> 26906 Edge weight: 53433
# 26527 --> 26907 Edge weight: 53434
# 26527 --> 26908 Edge weight: 53435
# 26527 --> 26909 Edge weight: 53436
# 26527 --> 26910 Edge weight: 53437
# 26527 --> 26911 Edge weight: 53438
# 26527 --> 26912 Edge weight: 53439
# 26527 --> 26913 Edge weight: 53440
# 26527 --> 26914 Edge weight: 53441
# 26527 --> 26915 Edge weight: 53442
# 26527 --> 26916 Edge weight: 53443
# 26527 --> 26917 Edge weight: 53444
# 26527 --> 26918 Edge weight: 53445
# 26527 --> 26919 Edge weight: 53446
# 26527 --> 26920 Edge weight: 53447
# 26527 --> 26921 Edge weight: 53448
# 26527 --> 26922 Edge weight: 53449
# 26527 --> 26923 Edge weight: 53450
# 26527 --> 26924 Edge weight: 53451
# 26527 --> 26925 Edge weight: 53452
# 26527 --> 26926 Edge weight: 53453
# 26527 --> 26927 Edge weight: 53454
# 26527 --> 26928 Edge weight: 53455
# 26527 --> 26929 Edge weight: 53456
# 26527 --> 26930 Edge weight: 53457
# 26527 --> 26931 Edge weight: 53458
# 26527 --> 26932 Edge weight: 53459
# 26527 --> 26933 Edge weight: 53460
# 26527 --> 26934 Edge weight: 53461
# 26527 --> 26935 Edge weight: 53462
# 26527 --> 26936 Edge weight: 53463
# 26527 --> 26937 Edge weight: 53464
# 26527 --> 26938 Edge weight: 53465
# 26527 --> 26939 Edge weight: 53466
# 26527 --> 26940 Edge weight: 53467
# 26527 --> 26941 Edge weight: 53468
# 26527 --> 26942 Edge weight: 53469
# 26527 --> 26943 Edge weight: 53470
# 26527 --> 26944 Edge weight: 53471
# 26527 --> 26945 Edge weight: 53472
# 26527 --> 26946 Edge weight: 53473
# 26527 --> 26947 Edge weight: 53474
# 26527 --> 26948 Edge weight: 53475
# 26527 --> 26949 Edge weight: 53476
# 26527 --> 26950 Edge weight: 53477
# 26527 --> 26951 Edge weight: 53478
# 26527 --> 26952 Edge weight: 53479
# 26527 --> 26953 Edge weight: 53480
# 26527 --> 26954 Edge weight: 53481
# 26527 --> 26955 Edge weight: 53482
# 26527 --> 26956 Edge weight: 53483
# 26527 --> 26957 Edge weight: 53484
# 26527 --> 26958 Edge weight: 53485
# 26527 --> 26959 Edge weight: 53486
# 26527 --> 26960 Edge weight: 53487
# 26527 --> 26961 Edge weight: 53488
# 26527 --> 26962 Edge weight: 53489
# 26527 --> 26963 Edge weight: 53490
# 26527 --> 26964 Edge weight: 53491
# 26527 --> 26965 Edge weight: 53492
# 26527 --> 26966 Edge weight: 53493
# 26527 --> 26967 Edge weight: 53494
# 26527 --> 26968 Edge weight: 53495
# 26527 --> 26969 Edge weight: 53496
# 26527 --> 26970 Edge weight: 53497
# 26527 --> 26971 Edge weight: 53498
# 26527 --> 26972 Edge weight: 53499
# 26527 --> 26973 Edge weight: 53500
# 26527 --> 26974 Edge weight: 53501
# 26527 --> 26975 Edge weight: 53502
# 26527 --> 26976 Edge weight: 53503
# 26527 --> 26977 Edge weight: 53504
# 26527 --> 26978 Edge weight: 53505
# 26527 --> 26979 Edge weight: 53506
# 26527 --> 26980 Edge weight: 53507
# 26527 --> 26981 Edge weight: 53508
# 26527 --> 26982 Edge weight: 53509
# 26527 --> 26983 Edge weight: 53510
# 26527 --> 26984 Edge weight: 53511
# 26527 --> 26985 Edge weight: 53512
# 26527 --> 26986 Edge weight: 53513
# 26527 --> 26987 Edge weight: 53514
# 26527 --> 26988 Edge weight: 53515
# 26527 --> 26989 Edge weight: 53516
# 26527 --> 26990 Edge weight: 53517
# 26527 --> 26991 Edge weight: 53518
# 26527 --> 26992 Edge weight: 53519
# 26527 --> 26993 Edge weight: 53520
# 26527 --> 26994 Edge weight: 53521
# 26527 --> 26995 Edge weight: 53522
# 26527 --> 26996 Edge weight: 53523
# 26527 --> 26997 Edge weight: 53524
# 26527 --> 26998 Edge weight: 53525
# 26527 --> 26999 Edge weight: 53526
# 26527 --> 27000 Edge weight: 53527
# 26527 --> 27001 Edge weight: 53528
# 26527 --> 27002 Edge weight: 53529
# 26527 --> 27003 Edge weight: 53530
# 26527 --> 27004 Edge weight: 53531
# 26527 --> 27005 Edge weight: 53532
# 26527 --> 27006 Edge weight: 53533
# 26527 --> 27007 Edge weight: 53534
# 26527 --> 27008 Edge weight: 53535
# 26527 --> 27009 Edge weight: 53536
# 26527 --> 27010 Edge weight: 53537
# 26527 --> 27011 Edge weight: 53538
# 26527 --> 27012 Edge weight: 53539
# 26527 --> 27013 Edge weight: 53540
# 26527 --> 27014 Edge weight: 53541
# 26527 --> 27015 Edge weight: 53542
# 26527 --> 27016 Edge weight: 53543
# 26527 --> 27017 Edge weight: 53544
# 26527 --> 27018 Edge weight: 53545
# 26527 --> 27019 Edge weight: 53546
# 26527 --> 27020 Edge weight: 53547
# 26527 --> 27021 Edge weight: 53548
# 26527 --> 27022 Edge weight: 53549
# 26527 --> 27023 Edge weight: 53550
# 26527 --> 27024 Edge weight: 53551
# 26527 --> 27025 Edge weight: 53552
# 26527 --> 27026 Edge weight: 53553
# leftNode
# 27027 --> 26528 Edge weight: 53555
# 27027 --> 26529 Edge weight: 53556
# 27027 --> 26530 Edge weight: 53557
# 27027 --> 26531 Edge weight: 53558
# 27027 --> 26532 Edge weight: 53559
# 27027 --> 26533 Edge weight: 53560
# 27027 --> 26534 Edge weight: 53561
# 27027 --> 26535 Edge weight: 53562
# 27027 --> 26536 Edge weight: 53563
# 27027 --> 26537 Edge weight: 53564
# 27027 --> 26538 Edge weight: 53565
# 27027 --> 26539 Edge weight: 53566
# 27027 --> 26540 Edge weight: 53567
# 27027 --> 26541 Edge weight: 53568
# 27027 --> 26542 Edge weight: 53569
# 27027 --> 26543 Edge weight: 53570
# 27027 --> 26544 Edge weight: 53571
# 27027 --> 26545 Edge weight: 53572
# 27027 --> 26546 Edge weight: 53573
# 27027 --> 26547 Edge weight: 53574
# 27027 --> 26548 Edge weight: 53575
# 27027 --> 26549 Edge weight: 53576
# 27027 --> 26550 Edge weight: 53577
# 27027 --> 26551 Edge weight: 53578
# 27027 --> 26552 Edge weight: 53579
# 27027 --> 26553 Edge weight: 53580
# 27027 --> 26554 Edge weight: 53581
# 27027 --> 26555 Edge weight: 53582
# 27027 --> 26556 Edge weight: 53583
# 27027 --> 26557 Edge weight: 53584
# 27027 --> 26558 Edge weight: 53585
# 27027 --> 26559 Edge weight: 53586
# 27027 --> 26560 Edge weight: 53587
# 27027 --> 26561 Edge weight: 53588
# 27027 --> 26562 Edge weight: 53589
# 27027 --> 26563 Edge weight: 53590
# 27027 --> 26564 Edge weight: 53591
# 27027 --> 26565 Edge weight: 53592
# 27027 --> 26566 Edge weight: 53593
# 27027 --> 26567 Edge weight: 53594
# 27027 --> 26568 Edge weight: 53595
# 27027 --> 26569 Edge weight: 53596
# 27027 --> 26570 Edge weight: 53597
# 27027 --> 26571 Edge weight: 53598
# 27027 --> 26572 Edge weight: 53599
# 27027 --> 26573 Edge weight: 53600
# 27027 --> 26574 Edge weight: 53601
# 27027 --> 26575 Edge weight: 53602
# 27027 --> 26576 Edge weight: 53603
# 27027 --> 26577 Edge weight: 53604
# 27027 --> 26578 Edge weight: 53605
# 27027 --> 26579 Edge weight: 53606
# 27027 --> 26580 Edge weight: 53607
# 27027 --> 26581 Edge weight: 53608
# 27027 --> 26582 Edge weight: 53609
# 27027 --> 26583 Edge weight: 53610
# 27027 --> 26584 Edge weight: 53611
# 27027 --> 26585 Edge weight: 53612
# 27027 --> 26586 Edge weight: 53613
# 27027 --> 26587 Edge weight: 53614
# 27027 --> 26588 Edge weight: 53615
# 27027 --> 26589 Edge weight: 53616
# 27027 --> 26590 Edge weight: 53617
# 27027 --> 26591 Edge weight: 53618
# 27027 --> 26592 Edge weight: 53619
# 27027 --> 26593 Edge weight: 53620
# 27027 --> 26594 Edge weight: 53621
# 27027 --> 26595 Edge weight: 53622
# 27027 --> 26596 Edge weight: 53623
# 27027 --> 26597 Edge weight: 53624
# 27027 --> 26598 Edge weight: 53625
# 27027 --> 26599 Edge weight: 53626
# 27027 --> 26600 Edge weight: 53627
# 27027 --> 26601 Edge weight: 53628
# 27027 --> 26602 Edge weight: 53629
# 27027 --> 26603 Edge weight: 53630
# 27027 --> 26604 Edge weight: 53631
# 27027 --> 26605 Edge weight: 53632
# 27027 --> 26606 Edge weight: 53633
# 27027 --> 26607 Edge weight: 53634
# 27027 --> 26608 Edge weight: 53635
# 27027 --> 26609 Edge weight: 53636
# 27027 --> 26610 Edge weight: 53637
# 27027 --> 26611 Edge weight: 53638
# 27027 --> 26612 Edge weight: 53639
# 27027 --> 26613 Edge weight: 53640
# 27027 --> 26614 Edge weight: 53641
# 27027 --> 26615 Edge weight: 53642
# 27027 --> 26616 Edge weight: 53643
# 27027 --> 26617 Edge weight: 53644
# 27027 --> 26618 Edge weight: 53645
# 27027 --> 26619 Edge weight: 53646
# 27027 --> 26620 Edge weight: 53647
# 27027 --> 26621 Edge weight: 53648
# 27027 --> 26622 Edge weight: 53649
# 27027 --> 26623 Edge weight: 53650
# 27027 --> 26624 Edge weight: 53651
# 27027 --> 26625 Edge weight: 53652
# 27027 --> 26626 Edge weight: 53653
# 27027 --> 26627 Edge weight: 53654
# 27027 --> 26628 Edge weight: 53655
# 27027 --> 26629 Edge weight: 53656
# 27027 --> 26630 Edge weight: 53657
# 27027 --> 26631 Edge weight: 53658
# 27027 --> 26632 Edge weight: 53659
# 27027 --> 26633 Edge weight: 53660
# 27027 --> 26634 Edge weight: 53661
# 27027 --> 26635 Edge weight: 53662
# 27027 --> 26636 Edge weight: 53663
# 27027 --> 26637 Edge weight: 53664
# 27027 --> 26638 Edge weight: 53665
# 27027 --> 26639 Edge weight: 53666
# 27027
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# #####
